# %% [markdown]
# ## MobileNet 2 layers

# %%
###### check gpu
import tensorflow as tf
from tensorflow.python.client import device_lib
import pandas as pd
import numpy as np
import glob
import random
import locale
from PIL import Image
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow import keras
#import tensorflow_addons as tfa
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4
from tensorflow.keras import layers, models, Model, Input
from tensorflow.keras.layers import concatenate, Input, Dense, Flatten, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint, History
from tensorflow.keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError, MeanSquaredError
from tensorflow.keras.utils import plot_model

from keras.layers.convolutional import Conv2D,MaxPooling2D
from keras.layers.core import Activation,Dropout,Dense
from tensorflow.keras.optimizers import Adam

import string
from keras.preprocessing import image as krs_image

# feature selection libraries
from sklearn.feature_selection import RFE

# %%
color_gt = ['RGB-R', 'RGB-G','RGB-B','HSL-H','HSL-S','HSL-L']
object_gt = ['aeroplane','apple','backpack','banana','baseball bat','baseball glove','bear','bed','bench','bicycle',
'bird','boat','book','bottle','bowl','broccoli','bus','cake','car','carrot','cat','cell phone','chair',
'clock','cow','cup','diningtable','dog','donut','elephant','fire hydrant','fork','frisbee','giraffe',
'handbag','horse','hot dog','keyboard','kite','knife','laptop','microwave','motorbike','mouse','orange',
'oven','parking meter','person','pizza','pottedplant','refrigerator','remote','sandwich','scissors','sheep',
'sink','skateboard','skis','snowboard','sofa','spoon','sports ball','stop sign','suitcase','surfboard',
'teddy bear','tennis racket','tie','toilet','toothbrush','traffic light','train','truck','tvmonitor','umbrella',
'vase','wine glass','zebra']
scene_gt = ['Indoor/Outdoor','shopping and dining','workplace (office building, factory, lab, etc.)',
'home or hotel','transportation (vehicle interiors, stations, etc.)','sports and leisure','cultural (art, education, religion, millitary, law, politics, etc.)',
'water, ice, snow','mountains, hills, desert, sky','forest, field, jungle','man-made elements','transportation (roads, parking, bridges, boats, airports, etc.)',
'cultural or historical building/place (millitary, religious)','sports fields, parks, leisure spaces','industrial and construction','houses, cabins, gardens, and farms',
'commercial buildings, shops, markets, cities, and towns','airfield','airplane_cabin','airport_terminal','alcove','alley','amphitheater','amusement_arcade',
'amusement_park','apartment_building/outdoor','aquarium','aqueduct','arcade','arch','archaelogical_excavation','archive','arena/hockey','arena/performance',
'arena/rodeo','army_base','art_gallery','art_school','art_studio','artists_loft','assembly_line','athletic_field/outdoor','atrium/public','attic','auditorium',
'auto_factory','auto_showroom','badlands','bakery/shop','balcony/exterior','balcony/interior','ball_pit','ballroom','bamboo_forest','bank_vault','banquet_hall',
'bar','barn','barndoor','baseball_field','basement','basketball_court/indoor','bathroom','bazaar/indoor','bazaar/outdoor','beach','beach_house','beauty_salon',
'bedchamber','bedroom','beer_garden','beer_hall','berth','biology_laboratory','boardwalk','boat_deck','boathouse','bookstore','booth/indoor','botanical_garden',
'bow_window/indoor','bowling_alley','boxing_ring','bridge','bullring','burial_chamber','bus_interior','bus_station/indoor','butchers_shop','butte','cabin/outdoor',
'campsite','campus','canal/natural','canal/urban','candy_store','canyon','car_interior','carrousel','castle','catacomb','cemetery','chalet','chemistry_lab',
'childs_room','church/indoor','church/outdoor','classroom','clean_room','cliff','closet','clothing_store','coast','cockpit','coffee_shop','computer_room',
'conference_center','conference_room','construction_site','corn_field','corral','corridor','cottage','courthouse','courtyard','creek','crevasse','crosswalk',
'dam','delicatessen','department_store','desert/sand','desert/vegetation','desert_road','diner/outdoor','dining_hall','dining_room','discotheque','doorway/outdoor',
'dorm_room','downtown','dressing_room','driveway','drugstore','elevator/door','elevator_lobby','elevator_shaft','embassy','engine_room','entrance_hall',
'escalator/indoor','excavation','fabric_store','farm','fastfood_restaurant','field/cultivated','field/wild','field_road','fire_escape','fire_station','fishpond',
'flea_market/indoor','florist_shop/indoor','food_court','football_field','forest/broadleaf','forest_path','forest_road','formal_garden','fountain','galley',
'garage/indoor','garage/outdoor','gas_station','gazebo/exterior','general_store/indoor','general_store/outdoor','gift_shop','glacier','golf_course','greenhouse/indoor',
'greenhouse/outdoor','grotto','gymnasium/indoor','hangar/indoor','hangar/outdoor','harbor','hardware_store','hayfield','heliport','highway','home_office',
'home_theater','hospital','hospital_room','hot_spring','hotel/outdoor','hotel_room','house','hunting_lodge/outdoor','ice_cream_parlor','ice_floe','ice_shelf',
'ice_skating_rink/indoor','ice_skating_rink/outdoor','iceberg','igloo','industrial_area','inn/outdoor','islet','jacuzzi/indoor','jail_cell','japanese_garden',
'jewelry_shop','junkyard','kasbah','kennel/outdoor','kindergarden_classroom','kitchen','lagoon','lake/natural','landfill','landing_deck','laundromat','lawn',
'lecture_room','legislative_chamber','library/indoor','library/outdoor','lighthouse','living_room','loading_dock','lobby','lock_chamber','locker_room','mansion',
'manufactured_home','market/indoor','market/outdoor','marsh','martial_arts_gym','mausoleum','medina','mezzanine','moat/water','mosque/outdoor','motel','mountain',
'mountain_path','mountain_snowy','movie_theater/indoor','museum/indoor','museum/outdoor','music_studio','natural_history_museum','nursery','nursing_home','oast_house',
'ocean','office','office_building','office_cubicles','oilrig','operating_room','orchard','orchestra_pit','pagoda','palace','pantry','park','parking_garage/indoor',
'parking_garage/outdoor','parking_lot','pasture','patio','pavilion','pet_shop','pharmacy','phone_booth','physics_laboratory','picnic_area','pier','pizzeria','playground',
'playroom','plaza','pond','porch','promenade','pub/indoor','racecourse','raceway','raft','railroad_track','rainforest','reception','recreation_room','repair_shop',
'residential_neighborhood','restaurant','restaurant_kitchen','restaurant_patio','rice_paddy','river','rock_arch','roof_garden','rope_bridge','ruin','runway','sandbox',
'sauna','schoolhouse','science_museum','server_room','shed','shoe_shop','shopfront','shopping_mall/indoor','shower','ski_resort','ski_slope','sky','skyscraper','slum',
'snowfield','soccer_field','stable','stadium/baseball','stadium/football','stadium/soccer','stage/indoor','stage/outdoor','staircase','storage_room','street',
'subway_station/platform','supermarket','sushi_bar','swamp','swimming_hole','swimming_pool/indoor','swimming_pool/outdoor','synagogue/outdoor','television_room',
'television_studio','temple/asia','throne_room','ticket_booth','topiary_garden','tower','toyshop','train_interior','train_station/platform','tree_farm','tree_house',
'trench','tundra','underwater/ocean_deep','utility_room','valley','vegetable_garden','veterinarians_office','viaduct','village','vineyard','volcano',
'volleyball_court/outdoor','waiting_room','water_park','water_tower','waterfall','watering_hole','wave','wet_bar','wheat_field','wind_farm','windmill','yard',
'youth_hostel','zen_garden']

# %%
# image features data in csv
train_x_data = pd.read_csv('../../data/train_x_rounded.csv', index_col ='iid')
test_x_data = pd.read_csv('../../data/test_x_rounded.csv',index_col ="iid")
valid_x_data = pd.read_csv('../../data/valid_x_rounded.csv',index_col ="iid")

# rejected_features = color_gt + scene_gt + ['boat', 'car_interior', 'forest, field, jungle', 'forest/broadleaf']
rejected_features = color_gt

train_x_data.drop(columns=rejected_features,inplace=True)
test_x_data.drop(columns=rejected_features,inplace=True)
valid_x_data.drop(columns=rejected_features,inplace=True)

trainAttrX = train_x_data

train_y_data = pd.read_csv('../../data/train_y.csv', index_col ='iid')
test_y_data = pd.read_csv('../../data/test_y.csv',index_col ="iid")
valid_y_data = pd.read_csv('../../data/valid_y.csv',index_col ="iid")

# %%
train_x_data
# Out:
#                 aeroplane  apple  backpack  banana  baseball bat  \
# iid
# I000259252.jpg          0      0         0       0             0
# I000296556.jpg          0      0         0       0             0
# I000193784.jpg          0      0         0       0             0
# I000793950.jpg          0      0         0       0             0
# I000872207.jpg          0      0         0       0             0
# I000583119.jpg          0      0         0       0             0
# I000981321.jpg          0      0         0       0             0
# I000149626.jpg          0      0         0       0             0
# I000833174.jpg          0      0         0       0             0
# I000257061.jpg          0      0         0       0             0
# I000765049.jpg          0      0         0       0             0
# I000918213.jpg          0      0         0       0             0
# I000394665.jpg          0      0         0       0             0
# I000671761.jpg          0      0         0       0             0
# I000273589.jpg          0      0         0       0             0
# I000442834.jpg          0      0         0       0             0
# I000002428.jpg          0      0         0       0             0
# I000313373.jpg          0      0         0       0             0
# I000142320.jpg          0      0         0       0             0
# I000656837.jpg          0      0         0       0             0
# I000677944.jpg          0      0         0       0             0
# I000096584.jpg          0      0         0       0             0
# I000099275.jpg          0      0         0       0             0
# I000574471.jpg          0      0         0       0             0
# I000217656.jpg          0      0         0       0             0
# I000746435.jpg          0      0         0       0             0
# I000477050.jpg          0      0         0       0             0
# I000668363.jpg          0      0         0       0             0
# I000418686.jpg          0      0         0       0             0
# I000300685.jpg          0      0         0       0             0
# ...                   ...    ...       ...     ...           ...
# I000703953.jpg          0      0         0       0             0
# I000830059.jpg          0      0         0       0             0
# I000432751.jpg          0      0         0       0             0
# I000811276.jpg          0      0         0       0             0
# I000731162.jpg          0      0         0       0             0
# I000042554.jpg          0      0         0       0             0
# I000245125.jpg          0      0         0       0             0
# I000326269.jpg          0      0         0       0             0
# I000883965.jpg          0      0         0       0             0
# I000359203.jpg          0      0         0       0             0
# I000669900.jpg          0      0         0       0             0
# I000072767.jpg          0      0         0       0             0
# I000836046.jpg          0      0         0       0             0
# I000799217.jpg          0      0         0       0             0
# I000777459.jpg          0      0         0       0             0
# I000737348.jpg          0      0         0       0             0
# I000011687.jpg          0      0         0       0             0
# I000798245.jpg          0      0         0       0             0
# I000828421.jpg          0      0         0       0             0
# I000487257.jpg          0      0         0       0             0
# I000214889.jpg          0      0         0       0             0
# I000743187.jpg          0      0         0       0             0
# I000520822.jpg          0      0         0       0             0
# I000447722.jpg          0      0         0       0             0
# I001005806.jpg          0      0         0       0             0
# I000087134.jpg          0      0         0       0             0
# I000681198.jpg          0      0         0       0             0
# I000942624.jpg          0      0         0       0             0
# I000013459.jpg          0      0         0       0             0
# I000212886.jpg          0      0         0       0             0
#
#                 baseball glove  bear  bed  bench  bicycle  ...  waterfall  \
# iid                                                        ...
# I000259252.jpg               0     0    0      0        0  ...          0
# I000296556.jpg               0     0    0      0        0  ...          0
# I000193784.jpg               0     0    0      0        0  ...          0
# I000793950.jpg               0     0    0      0        0  ...          0
# I000872207.jpg               0     1    0      0        0  ...          0
# I000583119.jpg               0     0    0      0        0  ...          0
# I000981321.jpg               0     0    0      0        0  ...          0
# I000149626.jpg               0     0    0      0        0  ...          0
# I000833174.jpg               0     0    0      0        0  ...          0
# I000257061.jpg               0     0    0      0        0  ...          0
# I000765049.jpg               0     0    0      0        0  ...          0
# I000918213.jpg               0     0    0      0        0  ...          0
# I000394665.jpg               0     1    0      0        0  ...          0
# I000671761.jpg               0     0    0      0        0  ...          0
# I000273589.jpg               0     0    0      0        0  ...          0
# I000442834.jpg               0     0    0      0        0  ...          0
# I000002428.jpg               0     0    0      0        0  ...          0
# I000313373.jpg               0     0    0      0        0  ...          0
# I000142320.jpg               0     0    0      0        0  ...          0
# I000656837.jpg               0     0    0      0        0  ...          0
# I000677944.jpg               0     0    0      0        0  ...          0
# I000096584.jpg               0     0    0      0        0  ...          0
# I000099275.jpg               0     0    0      0        0  ...          0
# I000574471.jpg               0     0    0      0        0  ...          0
# I000217656.jpg               0     0    0      0        0  ...          0
# I000746435.jpg               0     0    0      0        0  ...          0
# I000477050.jpg               0     0    0      0        0  ...          0
# I000668363.jpg               0     0    0      0        0  ...          0
# I000418686.jpg               0     0    0      0        0  ...          0
# I000300685.jpg               0     0    0      0        0  ...          0
# ...                        ...   ...  ...    ...      ...  ...        ...
# I000703953.jpg               0     0    0      0        0  ...          0
# I000830059.jpg               0     0    0      0        0  ...          0
# I000432751.jpg               0     0    0      0        0  ...          0
# I000811276.jpg               0     0    0      0        0  ...          0
# I000731162.jpg               0     0    0      0        0  ...          0
# I000042554.jpg               0     0    0      0        0  ...          0
# I000245125.jpg               0     0    0      0        0  ...          0
# I000326269.jpg               0     0    0      0        0  ...          0
# I000883965.jpg               0     0    0      0        0  ...          0
# I000359203.jpg               0     0    0      0        0  ...          0
# I000669900.jpg               0     0    0      0        0  ...          0
# I000072767.jpg               0     0    0      0        0  ...          0
# I000836046.jpg               0     0    0      0        0  ...          0
# I000799217.jpg               0     0    1      0        0  ...          0
# I000777459.jpg               0     0    0      0        0  ...          0
# I000737348.jpg               0     0    0      0        0  ...          0
# I000011687.jpg               0     0    0      0        0  ...          0
# I000798245.jpg               0     0    0      0        0  ...          0
# I000828421.jpg               0     0    0      0        0  ...          0
# I000487257.jpg               0     0    0      0        0  ...          0
# I000214889.jpg               0     0    0      0        0  ...          0
# I000743187.jpg               0     0    0      0        0  ...          0
# I000520822.jpg               0     0    0      0        0  ...          0
# I000447722.jpg               0     0    0      0        0  ...          0
# I001005806.jpg               0     0    0      0        0  ...          0
# I000087134.jpg               0     0    0      0        0  ...          0
# I000681198.jpg               0     0    0      0        0  ...          0
# I000942624.jpg               0     0    0      0        0  ...          0
# I000013459.jpg               0     0    0      0        0  ...          0
# I000212886.jpg               0     0    0      0        0  ...          0
#
#                 watering_hole  wave  wet_bar  wheat_field  wind_farm  \
# iid
# I000259252.jpg              0     0        0            0          0
# I000296556.jpg              0     0        0            0          0
# I000193784.jpg              0     0        0            0          0
# I000793950.jpg              0     0        0            0          0
# I000872207.jpg              0     0        0            0          0
# I000583119.jpg              0     0        0            0          0
# I000981321.jpg              0     0        0            0          0
# I000149626.jpg              0     0        0            0          0
# I000833174.jpg              0     0        0            0          0
# I000257061.jpg              0     0        0            0          0
# I000765049.jpg              0     0        0            0          0
# I000918213.jpg              0     0        0            0          0
# I000394665.jpg              0     0        0            0          0
# I000671761.jpg              0     0        0            0          0
# I000273589.jpg              0     0        0            0          0
# I000442834.jpg              0     0        0            0          0
# I000002428.jpg              0     0        0            0          0
# I000313373.jpg              0     0        0            0          0
# I000142320.jpg              0     0        0            0          0
# I000656837.jpg              0     0        0            0          0
# I000677944.jpg              0     0        0            0          0
# I000096584.jpg              0     0        0            0          0
# I000099275.jpg              0     0        0            0          0
# I000574471.jpg              0     0        0            0          0
# I000217656.jpg              0     0        0            0          0
# I000746435.jpg              0     0        0            0          0
# I000477050.jpg              0     0        0            0          0
# I000668363.jpg              0     0        0            0          0
# I000418686.jpg              0     0        0            0          0
# I000300685.jpg              0     0        0            0          0
# ...                       ...   ...      ...          ...        ...
# I000703953.jpg              0     0        0            0          0
# I000830059.jpg              0     0        0            0          0
# I000432751.jpg              0     0        0            0          0
# I000811276.jpg              0     0        0            0          0
# I000731162.jpg              0     0        0            0          0
# I000042554.jpg              0     0        0            0          0
# I000245125.jpg              0     0        0            0          0
# I000326269.jpg              0     0        0            0          0
# I000883965.jpg              0     0        0            0          0
# I000359203.jpg              0     0        0            0          0
# I000669900.jpg              0     0        0            0          0
# I000072767.jpg              0     0        0            0          0
# I000836046.jpg              0     0        0            0          0
# I000799217.jpg              0     0        0            0          0
# I000777459.jpg              0     0        0            0          0
# I000737348.jpg              0     0        0            0          0
# I000011687.jpg              0     0        0            0          0
# I000798245.jpg              0     0        0            0          0
# I000828421.jpg              0     0        0            0          0
# I000487257.jpg              0     0        0            0          0
# I000214889.jpg              0     0        0            0          0
# I000743187.jpg              0     0        0            0          0
# I000520822.jpg              0     0        0            0          0
# I000447722.jpg              0     0        0            0          0
# I001005806.jpg              0     0        0            0          0
# I000087134.jpg              0     0        0            0          0
# I000681198.jpg              0     0        0            0          0
# I000942624.jpg              0     0        0            0          0
# I000013459.jpg              0     0        0            0          0
# I000212886.jpg              0     0        0            0          0
#
#                 windmill  yard  youth_hostel  zen_garden
# iid
# I000259252.jpg         0     0             0           0
# I000296556.jpg         0     0             0           0
# I000193784.jpg         0     0             0           0
# I000793950.jpg         0     0             0           0
# I000872207.jpg         0     0             0           0
# I000583119.jpg         0     0             0           0
# I000981321.jpg         0     0             0           0
# I000149626.jpg         0     0             0           0
# I000833174.jpg         0     0             0           0
# I000257061.jpg         0     0             0           0
# I000765049.jpg         0     0             0           0
# I000918213.jpg         0     0             0           0
# I000394665.jpg         0     0             0           0
# I000671761.jpg         0     0             0           0
# I000273589.jpg         0     0             0           0
# I000442834.jpg         0     0             0           0
# I000002428.jpg         0     0             0           0
# I000313373.jpg         0     0             0           0
# I000142320.jpg         0     0             0           0
# I000656837.jpg         0     0             0           0
# I000677944.jpg         0     0             0           0
# I000096584.jpg         0     0             0           0
# I000099275.jpg         0     0             0           0
# I000574471.jpg         0     0             0           0
# I000217656.jpg         0     0             0           0
# I000746435.jpg         0     0             0           0
# I000477050.jpg         0     0             0           0
# I000668363.jpg         0     0             0           0
# I000418686.jpg         0     0             0           0
# I000300685.jpg         0     0             0           0
# ...                  ...   ...           ...         ...
# I000703953.jpg         0     0             0           0
# I000830059.jpg         0     0             0           0
# I000432751.jpg         0     0             0           0
# I000811276.jpg         0     0             0           0
# I000731162.jpg         0     0             0           0
# I000042554.jpg         0     0             0           0
# I000245125.jpg         0     0             0           0
# I000326269.jpg         0     0             0           0
# I000883965.jpg         0     0             0           0
# I000359203.jpg         0     0             0           0
# I000669900.jpg         0     0             0           0
# I000072767.jpg         0     0             0           0
# I000836046.jpg         0     0             0           0
# I000799217.jpg         0     0             0           0
# I000777459.jpg         0     0             0           0
# I000737348.jpg         0     0             0           0
# I000011687.jpg         0     0             0           0
# I000798245.jpg         0     0             0           0
# I000828421.jpg         0     0             0           0
# I000487257.jpg         0     0             0           0
# I000214889.jpg         0     0             0           0
# I000743187.jpg         0     0             0           0
# I000520822.jpg         0     0             0           0
# I000447722.jpg         0     0             0           0
# I001005806.jpg         0     0             0           0
# I000087134.jpg         0     0             0           0
# I000681198.jpg         0     0             0           0
# I000942624.jpg         0     0             0           0
# I000013459.jpg         0     0             0           0
# I000212886.jpg         0     0             0           0
#
# [58174 rows x 458 columns]

# %% [markdown]
# ### With Images

# %%
# image data 
train_file_list = glob.glob('../../train/*.jpg', recursive = True)
random.shuffle(train_file_list)

test_file_list = glob.glob('../../test/*.jpg', recursive = True)
random.shuffle(test_file_list)

valid_file_list = glob.glob('../../valid/*.jpg', recursive = True)
random.shuffle(valid_file_list)

# %%
train_file_list = [x for x in train_file_list if "(1)" not in x]

# %%
test_file_list = [x for x in test_file_list if "(1)" not in x]

# %%
valid_file_list = [x for x in valid_file_list if "(1)" not in x]

# %%
len(train_file_list)
# Out:
# 58174

# %%
len(test_file_list)
# Out:
# 12467

# %%
len(valid_file_list)
# Out:
# 12466

# %%
# data generator

# Create the arguments for image preprocessing
data_gen_args = dict(
    horizontal_flip=True,
    brightness_range=[0.5, 1.5],
    shear_range=10,
    channel_shift_range=50,
    rescale=1. / 255,
)

# Create an empty data generator
datagen = ImageDataGenerator()

def my_gen(images_list, dataframe, df_y, batch_size):
    i = 0
    while True:
        batch = {'img_input': [], 'csv_input': [], 'valence': [], 'arousal': [], 'dominance': []}
        for b in range(batch_size):
            if i == len(images_list):
                i = 0
                random.shuffle(images_list)
            # Read image from list and convert to array
            image_path = images_list[i]
            image_name = os.path.basename(image_path).replace('.JPG', '')
            #image = tf.keras.utils.load_img(image_path, target_size=(224, 224)) 
            image = krs_image.load_img(image_path, target_size=(224, 224)) #image height & width
            image = datagen.apply_transform(image, data_gen_args)
            image = krs_image.img_to_array(image)
            #image = tf.keras.utils.img_to_array(image)

            # Read data from csv using the name of current image
            csv_features = dataframe.loc[image_name, :]
            y = df_y.loc[image_name, :]
            val_train = y[0]
            aro_train = y[1]
            dom_train = y[2]

            #print(image_name)
            batch['img_input'].append(image)
            batch['csv_input'].append(csv_features)
            batch['valence'].append(val_train)
            batch['arousal'].append(aro_train)
            batch['dominance'].append(dom_train)

            i += 1

        batch['img_input'] = np.array(batch['img_input'])
        batch['csv_input'] = np.array(batch['csv_input'])
        batch['valence'] = np.array(batch['valence'])
        batch['arousal'] = np.array(batch['arousal'])
        batch['dominance'] = np.array(batch['dominance'])
        

        yield [batch['img_input']], [batch['valence'],batch['arousal'],batch['dominance']]

gen_train = my_gen(train_file_list, train_x_data, train_y_data, 32)
gen_test = my_gen(test_file_list, test_x_data, test_y_data, 32)
gen_valid = my_gen(valid_file_list, valid_x_data, valid_y_data, 32)

# %%
def create_mlp(dim):
	# define our MLP network
	model = Sequential()
	model.add(Dense(512, input_dim=dim, activation="relu", name='csv'))
	model.add(Dense(256, activation="relu"))
	model.add(Dense(128, activation="relu"))
	model.add(Dense(64, activation="relu"))    
    
	return model

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 

def create_mobilenet(width, height, depth):
    # inputs= Input(shape=(width, height, depth), name='img_input')  

    res = MobileNetV2(
        weights='imagenet',  
        include_top=False,  
        input_shape = (width, height, depth),  
    )

    for layer in res.layers:  
        layer.trainable = False #false: freeze, true:train by own

    x = layers.BatchNormalization()(res.output)
    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    x = layers.Flatten()(x)

    model = Model(res.input, x, name="ResNet")
    return model

# %%
mobilenet = create_mobilenet(224, 224, 3)
mobilenet.summary()
# Out:
# wise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 7, 7, 1280)   5120        out_relu[0][0]
# __________________________________________________________________________________________________
# top_dropout (Dropout)           (None, 7, 7, 1280)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 62720)        0           top_dropout[0][0]
# ==================================================================================================
# Total params: 2,263,104
# Trainable params: 2,560
# Non-trainable params: 2,260,544
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

x = Dense(1024, activation="relu",name='csv_img')(mobilenet.output)
x = Dense(512, activation="relu")(x)

valence_output = Dense(units=1, activation='linear', name='valence_output')(x)
arousal_output = Dense(units=1, activation='linear', name='arousal_output')(x)
dominance_output = Dense(units=1, activation='linear', name='dominance_output')(x)

model = Model(inputs=[mobilenet.input], outputs=[valence_output, arousal_output, dominance_output])

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt, run_eagerly=True,
              loss={'valence_output': 'mse', 'arousal_output': 'mse', 'dominance_output': 'mse'},
              metrics={'valence_output': 'mae', 'arousal_output': 'mae', 'dominance_output': 'mae'})
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-16-f1e66a0b7d7c> in <module>()
#       1 from tensorflow.keras.optimizers import Adam
#       2
# ----> 3 x = Dense(1024, activation="relu",name='csv_img')(mobilenet.output)
#       4 x = Dense(512, activation="relu")(x)
#       5
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1096         # Build layer if applicable (if the `build` method has been
#    1097         # overridden).
# -> 1098         self._maybe_build(inputs)
#    1099         cast_inputs = self._maybe_cast_inputs(inputs, input_list)
#    1100
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2641         # operations.
#    2642         with tf_utils.maybe_init_scope(self):
# -> 2643           self.build(input_shapes)  # pylint:disable=not-callable
#    2644       # We must set also ensure that the layer is marked as built, and the build
#    2645       # shape is stored since user defined build functions may not be calling
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py in build(self, input_shape)
#    1176         constraint=self.kernel_constraint,
#    1177         dtype=self.dtype,
# -> 1178         trainable=True)
#    1179     if self.use_bias:
#    1180       self.bias = self.add_weight(
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     612         synchronization=synchronization,
#     613         aggregation=aggregation,
# --> 614         caching_device=caching_device)
#     615     if regularizer is not None:
#     616       # TODO(fchollet): in the future, this should be handled at the
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     748         dtype=dtype,
#     749         initializer=initializer,
# --> 750         **kwargs_for_getter)
#     751
#     752     # If we set an initializer and the variable processed it, tracking will not
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     143       synchronization=synchronization,
#     144       aggregation=aggregation,
# --> 145       shape=variable_shape if variable_shape else None)
#     146
#     147
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     219         synchronization=synchronization,
#     220         aggregation=aggregation,
# --> 221         shape=shape)
#     222
#     223   def _variable_v2_call(cls,
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2595         synchronization=synchronization,
#    2596         aggregation=aggregation,
# -> 2597         shape=shape)
#    2598   else:
#    2599     return variables.RefVariable(
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1516           aggregation=aggregation,
#    1517           shape=shape,
# -> 1518           distribute_strategy=distribute_strategy)
#    1519
#    1520   def _init_from_args(self,
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1649           with ops.name_scope("Initializer"), device_context_manager(None):
#    1650             initial_value = ops.convert_to_tensor(
# -> 1651                 initial_value() if init_from_fn else initial_value,
#    1652                 name="initial_value", dtype=dtype)
#    1653           if shape is not None:
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/initializers/initializers_v2.py in __call__(self, shape, dtype)
#     395        (via `tf.keras.backend.set_floatx(float_dtype)`)
#     396     """
# --> 397     return super(VarianceScaling, self).__call__(shape, dtype=_get_dtype(dtype))
#     398
#     399
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/init_ops_v2.py in __call__(self, shape, dtype)
#     559     else:
#     560       limit = math.sqrt(3.0 * scale)
# --> 561       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     562
#     563   def get_config(self):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/init_ops_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#    1042       op = random_ops.random_uniform
#    1043     return op(
# -> 1044         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#    1045
#    1046   def truncated_normal(self, shape, mean, stddev, dtype):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     300     else:
#     301       result = gen_random_ops.random_uniform(
# --> 302           shape, dtype, seed=seed1, seed2=seed2)
#     303       if minval_is_zero:
#     304         if not maxval_is_one:
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_random_ops.py in random_uniform(shape, dtype, seed, seed2, name)
#     724       return _result
#     725     except _core._NotOkStatusException as e:
# --> 726       _ops.raise_from_not_ok_status(e, name)
#     727     except _core._FallbackException:
#     728       pass
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[62720,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]

# %%
model.summary()

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.0001),
    ModelCheckpoint('./trained_models/MobileNet', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
]

batch_size = 32
trainidx = len(train_file_list)
testidx = len(test_file_list)
valididx = len(valid_file_list)

# %%
history = model.fit(gen_train, epochs=1000, steps_per_epoch=trainidx/batch_size, validation_data=gen_valid, validation_steps=valididx/batch_size, callbacks=callbacks, batch_size=16)

def plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['dominance_output_mae'], label='Dominance Train MAE')
    axes[0].plot(history.history['val_dominance_output_mae'], label='Dominance Val MAE')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()

    axes[1].plot(history.history['arousal_output_mae'], label='Arousal Train MAE')
    axes[1].plot(history.history['val_arousal_output_mae'], label='Arousal Val MAE')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['valence_output_mae'], label='Valence Train MAE')
    axes[2].plot(history.history['val_valence_output_mae'], label='Valence Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

model.save('b4_mixedinput_fc_1024_512.h5')
# Out:
# nce_output_loss: 0.4410 - val_valence_output_mae: 0.8215 - val_arousal_output_mae: 0.4040 - val_dominance_output_mae: 0.5028
# Epoch 14/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.3081 - valence_output_loss: 0.6979 - arousal_output_loss: 0.3356 - dominance_output_loss: 0.2746 - valence_output_mae: 0.6573 - arousal_output_mae: 0.4212 - dominance_output_mae: 0.4036
# Epoch 00014: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 475s 262ms/step - loss: 1.3081 - valence_output_loss: 0.6979 - arousal_output_loss: 0.3356 - dominance_output_loss: 0.2746 - valence_output_mae: 0.6573 - arousal_output_mae: 0.4212 - dominance_output_mae: 0.4036 - val_loss: 1.8986 - val_valence_output_loss: 1.1274 - val_arousal_output_loss: 0.3377 - val_dominance_output_loss: 0.4335 - val_valence_output_mae: 0.8321 - val_arousal_output_mae: 0.4378 - val_dominance_output_mae: 0.5022
# Epoch 15/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 3.1443 - valence_output_loss: 1.4683 - arousal_output_loss: 1.2723 - dominance_output_loss: 0.4037 - valence_output_mae: 0.6653 - arousal_output_mae: 0.4334 - dominance_output_mae: 0.4108
# Epoch 00015: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 3.1443 - valence_output_loss: 1.4683 - arousal_output_loss: 1.2723 - dominance_output_loss: 0.4037 - valence_output_mae: 0.6653 - arousal_output_mae: 0.4334 - dominance_output_mae: 0.4108 - val_loss: 1.8563 - val_valence_output_loss: 1.1247 - val_arousal_output_loss: 0.2975 - val_dominance_output_loss: 0.4340 - val_valence_output_mae: 0.8341 - val_arousal_output_mae: 0.3914 - val_dominance_output_mae: 0.5044
# Epoch 16/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 5.7294 - valence_output_loss: 1.5882 - arousal_output_loss: 2.5239 - dominance_output_loss: 1.6173 - valence_output_mae: 0.6681 - arousal_output_mae: 0.4429 - dominance_output_mae: 0.4195
# Epoch 00016: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 474s 261ms/step - loss: 5.7294 - valence_output_loss: 1.5882 - arousal_output_loss: 2.5239 - dominance_output_loss: 1.6173 - valence_output_mae: 0.6681 - arousal_output_mae: 0.4429 - dominance_output_mae: 0.4195 - val_loss: 1.8484 - val_valence_output_loss: 1.1219 - val_arousal_output_loss: 0.2963 - val_dominance_output_loss: 0.4302 - val_valence_output_mae: 0.8321 - val_arousal_output_mae: 0.3911 - val_dominance_output_mae: 0.4999
# Epoch 17/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2372 - valence_output_loss: 0.6665 - arousal_output_loss: 0.3166 - dominance_output_loss: 0.2541 - valence_output_mae: 0.6424 - arousal_output_mae: 0.4057 - dominance_output_mae: 0.3863
# Epoch 00017: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.2372 - valence_output_loss: 0.6665 - arousal_output_loss: 0.3166 - dominance_output_loss: 0.2541 - valence_output_mae: 0.6424 - arousal_output_mae: 0.4057 - dominance_output_mae: 0.3863 - val_loss: 2.0415 - val_valence_output_loss: 1.2289 - val_arousal_output_loss: 0.2962 - val_dominance_output_loss: 0.5164 - val_valence_output_mae: 0.8666 - val_arousal_output_mae: 0.4005 - val_dominance_output_mae: 0.5458
# Epoch 18/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2396 - valence_output_loss: 0.6629 - arousal_output_loss: 0.3156 - dominance_output_loss: 0.2612 - valence_output_mae: 0.6417 - arousal_output_mae: 0.4049 - dominance_output_mae: 0.3933
# Epoch 00018: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 469s 258ms/step - loss: 1.2396 - valence_output_loss: 0.6629 - arousal_output_loss: 0.3156 - dominance_output_loss: 0.2612 - valence_output_mae: 0.6417 - arousal_output_mae: 0.4049 - dominance_output_mae: 0.3933 - val_loss: 1.9714 - val_valence_output_loss: 1.1912 - val_arousal_output_loss: 0.3145 - val_dominance_output_loss: 0.4657 - val_valence_output_mae: 0.8527 - val_arousal_output_mae: 0.4215 - val_dominance_output_mae: 0.5159
# Epoch 19/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2242 - valence_output_loss: 0.6536 - arousal_output_loss: 0.3128 - dominance_output_loss: 0.2579 - valence_output_mae: 0.6379 - arousal_output_mae: 0.4024 - dominance_output_mae: 0.3913
# Epoch 00019: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 468s 258ms/step - loss: 1.2242 - valence_output_loss: 0.6536 - arousal_output_loss: 0.3128 - dominance_output_loss: 0.2579 - valence_output_mae: 0.6379 - arousal_output_mae: 0.4024 - dominance_output_mae: 0.3913 - val_loss: 1.9288 - val_valence_output_loss: 1.2103 - val_arousal_output_loss: 0.2796 - val_dominance_output_loss: 0.4389 - val_valence_output_mae: 0.8737 - val_arousal_output_mae: 0.3798 - val_dominance_output_mae: 0.5084
# Epoch 20/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2093 - valence_output_loss: 0.6456 - arousal_output_loss: 0.3086 - dominance_output_loss: 0.2551 - valence_output_mae: 0.6337 - arousal_output_mae: 0.4000 - dominance_output_mae: 0.3893
# Epoch 00020: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 465s 256ms/step - loss: 1.2093 - valence_output_loss: 0.6456 - arousal_output_loss: 0.3086 - dominance_output_loss: 0.2551 - valence_output_mae: 0.6337 - arousal_output_mae: 0.4000 - dominance_output_mae: 0.3893 - val_loss: 1.9759 - val_valence_output_loss: 1.1728 - val_arousal_output_loss: 0.3711 - val_dominance_output_loss: 0.4320 - val_valence_output_mae: 0.8491 - val_arousal_output_mae: 0.4554 - val_dominance_output_mae: 0.5013
# Epoch 21/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2026 - valence_output_loss: 0.6416 - arousal_output_loss: 0.3046 - dominance_output_loss: 0.2564 - valence_output_mae: 0.6331 - arousal_output_mae: 0.3971 - dominance_output_mae: 0.3909
# Epoch 00021: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 467s 257ms/step - loss: 1.2026 - valence_output_loss: 0.6416 - arousal_output_loss: 0.3046 - dominance_output_loss: 0.2564 - valence_output_mae: 0.6331 - arousal_output_mae: 0.3971 - dominance_output_mae: 0.3909 - val_loss: 1.8812 - val_valence_output_loss: 1.1831 - val_arousal_output_loss: 0.2710 - val_dominance_output_loss: 0.4271 - val_valence_output_mae: 0.8577 - val_arousal_output_mae: 0.3707 - val_dominance_output_mae: 0.4994
# Epoch 22/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1926 - valence_output_loss: 0.6380 - arousal_output_loss: 0.3000 - dominance_output_loss: 0.2546 - valence_output_mae: 0.6308 - arousal_output_mae: 0.3934 - dominance_output_mae: 0.3880
# Epoch 00022: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 470s 258ms/step - loss: 1.1926 - valence_output_loss: 0.6380 - arousal_output_loss: 0.3000 - dominance_output_loss: 0.2546 - valence_output_mae: 0.6308 - arousal_output_mae: 0.3934 - dominance_output_mae: 0.3880 - val_loss: 1.9048 - val_valence_output_loss: 1.1920 - val_arousal_output_loss: 0.2770 - val_dominance_output_loss: 0.4357 - val_valence_output_mae: 0.8591 - val_arousal_output_mae: 0.3762 - val_dominance_output_mae: 0.5082
# Epoch 23/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1738 - valence_output_loss: 0.6281 - arousal_output_loss: 0.2963 - dominance_output_loss: 0.2494 - valence_output_mae: 0.6269 - arousal_output_mae: 0.3909 - dominance_output_mae: 0.3838
# Epoch 00023: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 470s 258ms/step - loss: 1.1738 - valence_output_loss: 0.6281 - arousal_output_loss: 0.2963 - dominance_output_loss: 0.2494 - valence_output_mae: 0.6269 - arousal_output_mae: 0.3909 - dominance_output_mae: 0.3838 - val_loss: 1.8815 - val_valence_output_loss: 1.1820 - val_arousal_output_loss: 0.2659 - val_dominance_output_loss: 0.4335 - val_valence_output_mae: 0.8563 - val_arousal_output_mae: 0.3702 - val_dominance_output_mae: 0.5066
# Epoch 24/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1608 - valence_output_loss: 0.6225 - arousal_output_loss: 0.2926 - dominance_output_loss: 0.2456 - valence_output_mae: 0.6234 - arousal_output_mae: 0.3882 - dominance_output_mae: 0.3804
# Epoch 00024: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.1608 - valence_output_loss: 0.6225 - arousal_output_loss: 0.2926 - dominance_output_loss: 0.2456 - valence_output_mae: 0.6234 - arousal_output_mae: 0.3882 - dominance_output_mae: 0.3804 - val_loss: 1.9229 - val_valence_output_loss: 1.2009 - val_arousal_output_loss: 0.2702 - val_dominance_output_loss: 0.4518 - val_valence_output_mae: 0.8587 - val_arousal_output_mae: 0.3705 - val_dominance_output_mae: 0.5083
# Epoch 25/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1549 - valence_output_loss: 0.6160 - arousal_output_loss: 0.2918 - dominance_output_loss: 0.2470 - valence_output_mae: 0.6213 - arousal_output_mae: 0.3862 - dominance_output_mae: 0.3810
# Epoch 00025: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.1549 - valence_output_loss: 0.6160 - arousal_output_loss: 0.2918 - dominance_output_loss: 0.2470 - valence_output_mae: 0.6213 - arousal_output_mae: 0.3862 - dominance_output_mae: 0.3810 - val_loss: 1.9622 - val_valence_output_loss: 1.2419 - val_arousal_output_loss: 0.2744 - val_dominance_output_loss: 0.4458 - val_valence_output_mae: 0.8736 - val_arousal_output_mae: 0.3772 - val_dominance_output_mae: 0.5050
# Epoch 26/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1428 - valence_output_loss: 0.6128 - arousal_output_loss: 0.2865 - dominance_output_loss: 0.2435 - valence_output_mae: 0.6185 - arousal_output_mae: 0.3840 - dominance_output_mae: 0.3774
# Epoch 00026: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.1428 - valence_output_loss: 0.6128 - arousal_output_loss: 0.2865 - dominance_output_loss: 0.2435 - valence_output_mae: 0.6185 - arousal_output_mae: 0.3840 - dominance_output_mae: 0.3774 - val_loss: 2.1133 - val_valence_output_loss: 1.2777 - val_arousal_output_loss: 0.3570 - val_dominance_output_loss: 0.4785 - val_valence_output_mae: 0.8945 - val_arousal_output_mae: 0.4668 - val_dominance_output_mae: 0.5439
# Epoch 27/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1459 - valence_output_loss: 0.6143 - arousal_output_loss: 0.2839 - dominance_output_loss: 0.2477 - valence_output_mae: 0.6177 - arousal_output_mae: 0.3817 - dominance_output_mae: 0.3774
# Epoch 00027: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 472s 260ms/step - loss: 1.1459 - valence_output_loss: 0.6143 - arousal_output_loss: 0.2839 - dominance_output_loss: 0.2477 - valence_output_mae: 0.6177 - arousal_output_mae: 0.3817 - dominance_output_mae: 0.3774 - val_loss: 1.9208 - val_valence_output_loss: 1.2270 - val_arousal_output_loss: 0.2752 - val_dominance_output_loss: 0.4186 - val_valence_output_mae: 0.8778 - val_arousal_output_mae: 0.3797 - val_dominance_output_mae: 0.4960
# Epoch 28/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1304 - valence_output_loss: 0.6082 - arousal_output_loss: 0.2827 - dominance_output_loss: 0.2394 - valence_output_mae: 0.6167 - arousal_output_mae: 0.3818 - dominance_output_mae: 0.3758
# Epoch 00028: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 474s 261ms/step - loss: 1.1304 - valence_output_loss: 0.6082 - arousal_output_loss: 0.2827 - dominance_output_loss: 0.2394 - valence_output_mae: 0.6167 - arousal_output_mae: 0.3818 - dominance_output_mae: 0.3758 - val_loss: 1.9252 - val_valence_output_loss: 1.2270 - val_arousal_output_loss: 0.2714 - val_dominance_output_loss: 0.4268 - val_valence_output_mae: 0.8633 - val_arousal_output_mae: 0.3717 - val_dominance_output_mae: 0.5008
# Epoch 29/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1243 - valence_output_loss: 0.6048 - arousal_output_loss: 0.2805 - dominance_output_loss: 0.2390 - valence_output_mae: 0.6162 - arousal_output_mae: 0.3797 - dominance_output_mae: 0.3747
# Epoch 00029: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.1243 - valence_output_loss: 0.6048 - arousal_output_loss: 0.2805 - dominance_output_loss: 0.2390 - valence_output_mae: 0.6162 - arousal_output_mae: 0.3797 - dominance_output_mae: 0.3747 - val_loss: 1.9649 - val_valence_output_loss: 1.2581 - val_arousal_output_loss: 0.2645 - val_dominance_output_loss: 0.4422 - val_valence_output_mae: 0.8799 - val_arousal_output_mae: 0.3669 - val_dominance_output_mae: 0.5028
# Epoch 30/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.6771 - valence_output_loss: 0.6489 - arousal_output_loss: 0.5820 - dominance_output_loss: 0.4462 - valence_output_mae: 0.6167 - arousal_output_mae: 0.3867 - dominance_output_mae: 0.3779
# Epoch 00030: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.6771 - valence_output_loss: 0.6489 - arousal_output_loss: 0.5820 - dominance_output_loss: 0.4462 - valence_output_mae: 0.6167 - arousal_output_mae: 0.3867 - dominance_output_mae: 0.3779 - val_loss: 1.9278 - val_valence_output_loss: 1.2346 - val_arousal_output_loss: 0.2729 - val_dominance_output_loss: 0.4203 - val_valence_output_mae: 0.8682 - val_arousal_output_mae: 0.3758 - val_dominance_output_mae: 0.4912
# Epoch 31/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.2680 - valence_output_loss: 0.6826 - arousal_output_loss: 0.3274 - dominance_output_loss: 0.2580 - valence_output_mae: 0.6156 - arousal_output_mae: 0.3801 - dominance_output_mae: 0.3736
# Epoch 00031: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 475s 261ms/step - loss: 1.2680 - valence_output_loss: 0.6826 - arousal_output_loss: 0.3274 - dominance_output_loss: 0.2580 - valence_output_mae: 0.6156 - arousal_output_mae: 0.3801 - dominance_output_mae: 0.3736 - val_loss: 1.9088 - val_valence_output_loss: 1.2120 - val_arousal_output_loss: 0.2696 - val_dominance_output_loss: 0.4272 - val_valence_output_mae: 0.8651 - val_arousal_output_mae: 0.3699 - val_dominance_output_mae: 0.5020
# Epoch 32/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1138 - valence_output_loss: 0.6016 - arousal_output_loss: 0.2779 - dominance_output_loss: 0.2343 - valence_output_mae: 0.6129 - arousal_output_mae: 0.3790 - dominance_output_mae: 0.3698
# Epoch 00032: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 475s 261ms/step - loss: 1.1138 - valence_output_loss: 0.6016 - arousal_output_loss: 0.2779 - dominance_output_loss: 0.2343 - valence_output_mae: 0.6129 - arousal_output_mae: 0.3790 - dominance_output_mae: 0.3698 - val_loss: 1.9491 - val_valence_output_loss: 1.2384 - val_arousal_output_loss: 0.2658 - val_dominance_output_loss: 0.4449 - val_valence_output_mae: 0.8811 - val_arousal_output_mae: 0.3715 - val_dominance_output_mae: 0.5230
# Epoch 33/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1026 - valence_output_loss: 0.5937 - arousal_output_loss: 0.2766 - dominance_output_loss: 0.2323 - valence_output_mae: 0.6104 - arousal_output_mae: 0.3782 - dominance_output_mae: 0.3696
# Epoch 00033: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 474s 261ms/step - loss: 1.1026 - valence_output_loss: 0.5937 - arousal_output_loss: 0.2766 - dominance_output_loss: 0.2323 - valence_output_mae: 0.6104 - arousal_output_mae: 0.3782 - dominance_output_mae: 0.3696 - val_loss: 1.9363 - val_valence_output_loss: 1.2477 - val_arousal_output_loss: 0.2731 - val_dominance_output_loss: 0.4156 - val_valence_output_mae: 0.8848 - val_arousal_output_mae: 0.3734 - val_dominance_output_mae: 0.4922
# Epoch 34/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1024 - valence_output_loss: 0.5920 - arousal_output_loss: 0.2778 - dominance_output_loss: 0.2327 - valence_output_mae: 0.6092 - arousal_output_mae: 0.3794 - dominance_output_mae: 0.3690
# Epoch 00034: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 472s 259ms/step - loss: 1.1024 - valence_output_loss: 0.5920 - arousal_output_loss: 0.2778 - dominance_output_loss: 0.2327 - valence_output_mae: 0.6092 - arousal_output_mae: 0.3794 - dominance_output_mae: 0.3690 - val_loss: 1.9149 - val_valence_output_loss: 1.2267 - val_arousal_output_loss: 0.2684 - val_dominance_output_loss: 0.4198 - val_valence_output_mae: 0.8722 - val_arousal_output_mae: 0.3710 - val_dominance_output_mae: 0.4966
# Epoch 35/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.0861 - valence_output_loss: 0.5835 - arousal_output_loss: 0.2739 - dominance_output_loss: 0.2287 - valence_output_mae: 0.6040 - arousal_output_mae: 0.3761 - dominance_output_mae: 0.3662
# Epoch 00035: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 476s 262ms/step - loss: 1.0861 - valence_output_loss: 0.5835 - arousal_output_loss: 0.2739 - dominance_output_loss: 0.2287 - valence_output_mae: 0.6040 - arousal_output_mae: 0.3761 - dominance_output_mae: 0.3662 - val_loss: 1.9951 - val_valence_output_loss: 1.2941 - val_arousal_output_loss: 0.2855 - val_dominance_output_loss: 0.4154 - val_valence_output_mae: 0.8856 - val_arousal_output_mae: 0.3845 - val_dominance_output_mae: 0.4895
# Epoch 36/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.0935 - valence_output_loss: 0.5876 - arousal_output_loss: 0.2751 - dominance_output_loss: 0.2308 - valence_output_mae: 0.6071 - arousal_output_mae: 0.3782 - dominance_output_mae: 0.3672
# Epoch 00036: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 476s 262ms/step - loss: 1.0935 - valence_output_loss: 0.5876 - arousal_output_loss: 0.2751 - dominance_output_loss: 0.2308 - valence_output_mae: 0.6071 - arousal_output_mae: 0.3782 - dominance_output_mae: 0.3672 - val_loss: 1.9504 - val_valence_output_loss: 1.2256 - val_arousal_output_loss: 0.3130 - val_dominance_output_loss: 0.4119 - val_valence_output_mae: 0.8704 - val_arousal_output_mae: 0.4109 - val_dominance_output_mae: 0.4885
# Epoch 37/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5531 - valence_output_loss: 0.7506 - arousal_output_loss: 0.4427 - dominance_output_loss: 0.3598 - valence_output_mae: 0.6098 - arousal_output_mae: 0.3806 - dominance_output_mae: 0.3685
# Epoch 00037: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 473s 260ms/step - loss: 1.5531 - valence_output_loss: 0.7506 - arousal_output_loss: 0.4427 - dominance_output_loss: 0.3598 - valence_output_mae: 0.6098 - arousal_output_mae: 0.3806 - dominance_output_mae: 0.3685 - val_loss: 2.0736 - val_valence_output_loss: 1.3539 - val_arousal_output_loss: 0.2726 - val_dominance_output_loss: 0.4472 - val_valence_output_mae: 0.9141 - val_arousal_output_mae: 0.3745 - val_dominance_output_mae: 0.5037
# Epoch 38/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.0786 - valence_output_loss: 0.5779 - arousal_output_loss: 0.2744 - dominance_output_loss: 0.2263 - valence_output_mae: 0.6006 - arousal_output_mae: 0.3775 - dominance_output_mae: 0.3628
# Epoch 00038: val_loss did not improve from 1.82243
# 1818/1817 [==============================] - 475s 261ms/step - loss: 1.0786 - valence_output_loss: 0.5779 - arousal_output_loss: 0.2744 - dominance_output_loss: 0.2263 - valence_output_mae: 0.6006 - arousal_output_mae: 0.3775 - dominance_output_mae: 0.3628 - val_loss: 1.9698 - val_valence_output_loss: 1.2577 - val_arousal_output_loss: 0.2668 - val_dominance_output_loss: 0.4453 - val_valence_output_mae: 0.8802 - val_arousal_output_mae: 0.3712 - val_dominance_output_mae: 0.5019

# %% [markdown]
# ### Fine-tuning

# %%
from tensorflow.keras.models import load_model

model = load_model("./trained_models/MobileNet")

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[:fine_tune_at]:
  layer.trainable = False

for layer in model.layers[fine_tune_at:]:
  layer.trainable = True
# Out:
# Number of layers in the base model:  162

# %%
model.summary()
# Out:
# [0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 7, 7, 1280)   5120        out_relu[0][0]
# __________________________________________________________________________________________________
# top_dropout (Dropout)           (None, 7, 7, 1280)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 62720)        0           top_dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          32113152    flatten[0][0]
# __________________________________________________________________________________________________
# valence_output (Dense)          (None, 1)            513         dense_1[0][0]
# __________________________________________________________________________________________________
# arousal_output (Dense)          (None, 1)            513         dense_1[0][0]
# __________________________________________________________________________________________________
# dominance_output (Dense)        (None, 1)            513         dense_1[0][0]
# ==================================================================================================
# Total params: 34,377,795
# Trainable params: 33,979,843
# Non-trainable params: 397,952
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.0001)

model.compile(optimizer=opt, run_eagerly=True,
              loss={'valence_output': 'mse', 'arousal_output': 'mse', 'dominance_output': 'mse'},
              metrics={'valence_output': 'mae', 'arousal_output': 'mae', 'dominance_output': 'mae'})

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.0001),
    ModelCheckpoint('./trained_models/MobileNet_finetuned', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
]

batch_size = 32
trainidx = len(train_file_list)
testidx = len(test_file_list)
valididx = len(valid_file_list)

# %%
history = model.fit(gen_train, epochs=1000, steps_per_epoch=trainidx/batch_size, validation_data=gen_valid, validation_steps=valididx/batch_size, callbacks=callbacks, batch_size=32)

def plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['dominance_output_mae'], label='Dominance Train MAE')
    axes[0].plot(history.history['val_dominance_output_mae'], label='Dominance Val MAE')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()

    axes[1].plot(history.history['arousal_output_mae'], label='Arousal Train MAE')
    axes[1].plot(history.history['val_arousal_output_mae'], label='Arousal Val MAE')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['valence_output_mae'], label='Valence Train MAE')
    axes[2].plot(history.history['val_valence_output_mae'], label='Valence Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

model.save('b4_mixedinput_fc_1024_512.h5')
# Out:
# Epoch 1/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.7024 - valence_output_loss: 1.0243 - arousal_output_loss: 0.2994 - dominance_output_loss: 0.3786 - valence_output_mae: 0.7921 - arousal_output_mae: 0.3971 - dominance_output_mae: 0.4623
# Epoch 00001: val_loss improved from inf to 1.69112, saving model to ./trained_models/MobileNet_finetuned
# WARNING:tensorflow:From /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./trained_models/MobileNet_finetuned/assets
# 1818/1817 [==============================] - 389s 214ms/step - loss: 1.7024 - valence_output_loss: 1.0243 - arousal_output_loss: 0.2994 - dominance_output_loss: 0.3786 - valence_output_mae: 0.7921 - arousal_output_mae: 0.3971 - dominance_output_mae: 0.4623 - val_loss: 1.6911 - val_valence_output_loss: 1.0265 - val_arousal_output_loss: 0.2928 - val_dominance_output_loss: 0.3719 - val_valence_output_mae: 0.7977 - val_arousal_output_mae: 0.3957 - val_dominance_output_mae: 0.4625
# Epoch 2/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5849 - valence_output_loss: 0.9474 - arousal_output_loss: 0.2990 - dominance_output_loss: 0.3385 - valence_output_mae: 0.7616 - arousal_output_mae: 0.3947 - dominance_output_mae: 0.4353
# Epoch 00002: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 377s 208ms/step - loss: 1.5849 - valence_output_loss: 0.9474 - arousal_output_loss: 0.2990 - dominance_output_loss: 0.3385 - valence_output_mae: 0.7616 - arousal_output_mae: 0.3947 - dominance_output_mae: 0.4353 - val_loss: 1.8047 - val_valence_output_loss: 1.0803 - val_arousal_output_loss: 0.3170 - val_dominance_output_loss: 0.4073 - val_valence_output_mae: 0.8261 - val_arousal_output_mae: 0.4097 - val_dominance_output_mae: 0.4941
# Epoch 3/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4718 - valence_output_loss: 0.8654 - arousal_output_loss: 0.3052 - dominance_output_loss: 0.3011 - valence_output_mae: 0.7255 - arousal_output_mae: 0.3994 - dominance_output_mae: 0.4103
# Epoch 00003: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 376s 207ms/step - loss: 1.4718 - valence_output_loss: 0.8654 - arousal_output_loss: 0.3052 - dominance_output_loss: 0.3011 - valence_output_mae: 0.7255 - arousal_output_mae: 0.3994 - dominance_output_mae: 0.4103 - val_loss: 1.7474 - val_valence_output_loss: 1.0501 - val_arousal_output_loss: 0.3013 - val_dominance_output_loss: 0.3961 - val_valence_output_mae: 0.8042 - val_arousal_output_mae: 0.3981 - val_dominance_output_mae: 0.4772
# Epoch 4/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.3362 - valence_output_loss: 0.7464 - arousal_output_loss: 0.3305 - dominance_output_loss: 0.2593 - valence_output_mae: 0.6754 - arousal_output_mae: 0.4177 - dominance_output_mae: 0.3832
# Epoch 00004: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 381s 209ms/step - loss: 1.3362 - valence_output_loss: 0.7464 - arousal_output_loss: 0.3305 - dominance_output_loss: 0.2593 - valence_output_mae: 0.6754 - arousal_output_mae: 0.4177 - dominance_output_mae: 0.3832 - val_loss: 1.8564 - val_valence_output_loss: 1.0935 - val_arousal_output_loss: 0.3267 - val_dominance_output_loss: 0.4362 - val_valence_output_mae: 0.8259 - val_arousal_output_mae: 0.4195 - val_dominance_output_mae: 0.5096
# Epoch 5/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1947 - valence_output_loss: 0.6173 - arousal_output_loss: 0.3611 - dominance_output_loss: 0.2163 - valence_output_mae: 0.6136 - arousal_output_mae: 0.4349 - dominance_output_mae: 0.3529
# Epoch 00005: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 372s 204ms/step - loss: 1.1947 - valence_output_loss: 0.6173 - arousal_output_loss: 0.3611 - dominance_output_loss: 0.2163 - valence_output_mae: 0.6136 - arousal_output_mae: 0.4349 - dominance_output_mae: 0.3529 - val_loss: 1.8707 - val_valence_output_loss: 1.1042 - val_arousal_output_loss: 0.3259 - val_dominance_output_loss: 0.4405 - val_valence_output_mae: 0.8324 - val_arousal_output_mae: 0.4195 - val_dominance_output_mae: 0.5102
# Epoch 6/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.1014 - valence_output_loss: 0.5268 - arousal_output_loss: 0.3877 - dominance_output_loss: 0.1869 - valence_output_mae: 0.5658 - arousal_output_mae: 0.4499 - dominance_output_mae: 0.3305
# Epoch 00006: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 369s 203ms/step - loss: 1.1014 - valence_output_loss: 0.5268 - arousal_output_loss: 0.3877 - dominance_output_loss: 0.1869 - valence_output_mae: 0.5658 - arousal_output_mae: 0.4499 - dominance_output_mae: 0.3305 - val_loss: 1.8704 - val_valence_output_loss: 1.1073 - val_arousal_output_loss: 0.3212 - val_dominance_output_loss: 0.4418 - val_valence_output_mae: 0.8267 - val_arousal_output_mae: 0.4154 - val_dominance_output_mae: 0.5065
# Epoch 7/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.0342 - valence_output_loss: 0.4644 - arousal_output_loss: 0.4016 - dominance_output_loss: 0.1683 - valence_output_mae: 0.5324 - arousal_output_mae: 0.4577 - dominance_output_mae: 0.3147
# Epoch 00007: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 371s 204ms/step - loss: 1.0342 - valence_output_loss: 0.4644 - arousal_output_loss: 0.4016 - dominance_output_loss: 0.1683 - valence_output_mae: 0.5324 - arousal_output_mae: 0.4577 - dominance_output_mae: 0.3147 - val_loss: 1.8519 - val_valence_output_loss: 1.0937 - val_arousal_output_loss: 0.3186 - val_dominance_output_loss: 0.4396 - val_valence_output_mae: 0.8230 - val_arousal_output_mae: 0.4155 - val_dominance_output_mae: 0.5124
# Epoch 8/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.9750 - valence_output_loss: 0.4183 - arousal_output_loss: 0.4023 - dominance_output_loss: 0.1543 - valence_output_mae: 0.5044 - arousal_output_mae: 0.4576 - dominance_output_mae: 0.3014
# Epoch 00008: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 368s 202ms/step - loss: 0.9750 - valence_output_loss: 0.4183 - arousal_output_loss: 0.4023 - dominance_output_loss: 0.1543 - valence_output_mae: 0.5044 - arousal_output_mae: 0.4576 - dominance_output_mae: 0.3014 - val_loss: 1.8407 - val_valence_output_loss: 1.0965 - val_arousal_output_loss: 0.3161 - val_dominance_output_loss: 0.4281 - val_valence_output_mae: 0.8220 - val_arousal_output_mae: 0.4114 - val_dominance_output_mae: 0.5004
# Epoch 9/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.9503 - valence_output_loss: 0.3905 - arousal_output_loss: 0.4134 - dominance_output_loss: 0.1465 - valence_output_mae: 0.4878 - arousal_output_mae: 0.4634 - dominance_output_mae: 0.2942
# Epoch 00009: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 369s 203ms/step - loss: 0.9503 - valence_output_loss: 0.3905 - arousal_output_loss: 0.4134 - dominance_output_loss: 0.1465 - valence_output_mae: 0.4878 - arousal_output_mae: 0.4634 - dominance_output_mae: 0.2942 - val_loss: 1.9937 - val_valence_output_loss: 1.1586 - val_arousal_output_loss: 0.3556 - val_dominance_output_loss: 0.4795 - val_valence_output_mae: 0.8530 - val_arousal_output_mae: 0.4398 - val_dominance_output_mae: 0.5408
# Epoch 10/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.9206 - valence_output_loss: 0.3669 - arousal_output_loss: 0.4143 - dominance_output_loss: 0.1394 - valence_output_mae: 0.4733 - arousal_output_mae: 0.4639 - dominance_output_mae: 0.2868
# Epoch 00010: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 367s 202ms/step - loss: 0.9206 - valence_output_loss: 0.3669 - arousal_output_loss: 0.4143 - dominance_output_loss: 0.1394 - valence_output_mae: 0.4733 - arousal_output_mae: 0.4639 - dominance_output_mae: 0.2868 - val_loss: 1.8715 - val_valence_output_loss: 1.1048 - val_arousal_output_loss: 0.3216 - val_dominance_output_loss: 0.4451 - val_valence_output_mae: 0.8278 - val_arousal_output_mae: 0.4156 - val_dominance_output_mae: 0.5146
# Epoch 11/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.9022 - valence_output_loss: 0.3495 - arousal_output_loss: 0.4178 - dominance_output_loss: 0.1350 - valence_output_mae: 0.4616 - arousal_output_mae: 0.4632 - dominance_output_mae: 0.2822
# Epoch 00011: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 369s 203ms/step - loss: 0.9022 - valence_output_loss: 0.3495 - arousal_output_loss: 0.4178 - dominance_output_loss: 0.1350 - valence_output_mae: 0.4616 - arousal_output_mae: 0.4632 - dominance_output_mae: 0.2822 - val_loss: 1.8836 - val_valence_output_loss: 1.1217 - val_arousal_output_loss: 0.3201 - val_dominance_output_loss: 0.4417 - val_valence_output_mae: 0.8317 - val_arousal_output_mae: 0.4201 - val_dominance_output_mae: 0.5111
# Epoch 12/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.8764 - valence_output_loss: 0.3289 - arousal_output_loss: 0.4162 - dominance_output_loss: 0.1313 - valence_output_mae: 0.4476 - arousal_output_mae: 0.4631 - dominance_output_mae: 0.2781
# Epoch 00012: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 370s 203ms/step - loss: 0.8764 - valence_output_loss: 0.3289 - arousal_output_loss: 0.4162 - dominance_output_loss: 0.1313 - valence_output_mae: 0.4476 - arousal_output_mae: 0.4631 - dominance_output_mae: 0.2781 - val_loss: 1.8306 - val_valence_output_loss: 1.0969 - val_arousal_output_loss: 0.3066 - val_dominance_output_loss: 0.4270 - val_valence_output_mae: 0.8223 - val_arousal_output_mae: 0.4037 - val_dominance_output_mae: 0.5037
# Epoch 13/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.8556 - valence_output_loss: 0.3144 - arousal_output_loss: 0.4159 - dominance_output_loss: 0.1253 - valence_output_mae: 0.4373 - arousal_output_mae: 0.4612 - dominance_output_mae: 0.2718
# Epoch 00013: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 370s 204ms/step - loss: 0.8556 - valence_output_loss: 0.3144 - arousal_output_loss: 0.4159 - dominance_output_loss: 0.1253 - valence_output_mae: 0.4373 - arousal_output_mae: 0.4612 - dominance_output_mae: 0.2718 - val_loss: 1.9085 - val_valence_output_loss: 1.1247 - val_arousal_output_loss: 0.3452 - val_dominance_output_loss: 0.4386 - val_valence_output_mae: 0.8350 - val_arousal_output_mae: 0.4334 - val_dominance_output_mae: 0.5100
# Epoch 14/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.8288 - valence_output_loss: 0.2949 - arousal_output_loss: 0.4134 - dominance_output_loss: 0.1205 - valence_output_mae: 0.4240 - arousal_output_mae: 0.4608 - dominance_output_mae: 0.2663
# Epoch 00014: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 373s 205ms/step - loss: 0.8288 - valence_output_loss: 0.2949 - arousal_output_loss: 0.4134 - dominance_output_loss: 0.1205 - valence_output_mae: 0.4240 - arousal_output_mae: 0.4608 - dominance_output_mae: 0.2663 - val_loss: 1.8486 - val_valence_output_loss: 1.1061 - val_arousal_output_loss: 0.3050 - val_dominance_output_loss: 0.4374 - val_valence_output_mae: 0.8236 - val_arousal_output_mae: 0.4021 - val_dominance_output_mae: 0.5004
# Epoch 15/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.8155 - valence_output_loss: 0.2845 - arousal_output_loss: 0.4119 - dominance_output_loss: 0.1191 - valence_output_mae: 0.4160 - arousal_output_mae: 0.4601 - dominance_output_mae: 0.2647
# Epoch 00015: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 371s 204ms/step - loss: 0.8155 - valence_output_loss: 0.2845 - arousal_output_loss: 0.4119 - dominance_output_loss: 0.1191 - valence_output_mae: 0.4160 - arousal_output_mae: 0.4601 - dominance_output_mae: 0.2647 - val_loss: 1.8289 - val_valence_output_loss: 1.1056 - val_arousal_output_loss: 0.2982 - val_dominance_output_loss: 0.4251 - val_valence_output_mae: 0.8250 - val_arousal_output_mae: 0.4012 - val_dominance_output_mae: 0.4958
# Epoch 16/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.8093 - valence_output_loss: 0.2727 - arousal_output_loss: 0.4195 - dominance_output_loss: 0.1170 - valence_output_mae: 0.4076 - arousal_output_mae: 0.4631 - dominance_output_mae: 0.2621
# Epoch 00016: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 374s 205ms/step - loss: 0.8093 - valence_output_loss: 0.2727 - arousal_output_loss: 0.4195 - dominance_output_loss: 0.1170 - valence_output_mae: 0.4076 - arousal_output_mae: 0.4631 - dominance_output_mae: 0.2621 - val_loss: 1.8244 - val_valence_output_loss: 1.0988 - val_arousal_output_loss: 0.3067 - val_dominance_output_loss: 0.4190 - val_valence_output_mae: 0.8253 - val_arousal_output_mae: 0.4009 - val_dominance_output_mae: 0.4947
# Epoch 17/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7855 - valence_output_loss: 0.2582 - arousal_output_loss: 0.4140 - dominance_output_loss: 0.1133 - valence_output_mae: 0.3968 - arousal_output_mae: 0.4585 - dominance_output_mae: 0.2578
# Epoch 00017: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 373s 205ms/step - loss: 0.7855 - valence_output_loss: 0.2582 - arousal_output_loss: 0.4140 - dominance_output_loss: 0.1133 - valence_output_mae: 0.3968 - arousal_output_mae: 0.4585 - dominance_output_mae: 0.2578 - val_loss: 1.8516 - val_valence_output_loss: 1.1212 - val_arousal_output_loss: 0.3018 - val_dominance_output_loss: 0.4286 - val_valence_output_mae: 0.8298 - val_arousal_output_mae: 0.4033 - val_dominance_output_mae: 0.5019
# Epoch 18/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7722 - valence_output_loss: 0.2503 - arousal_output_loss: 0.4112 - dominance_output_loss: 0.1107 - valence_output_mae: 0.3903 - arousal_output_mae: 0.4573 - dominance_output_mae: 0.2546
# Epoch 00018: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 370s 204ms/step - loss: 0.7722 - valence_output_loss: 0.2503 - arousal_output_loss: 0.4112 - dominance_output_loss: 0.1107 - valence_output_mae: 0.3903 - arousal_output_mae: 0.4573 - dominance_output_mae: 0.2546 - val_loss: 1.8303 - val_valence_output_loss: 1.1073 - val_arousal_output_loss: 0.2978 - val_dominance_output_loss: 0.4251 - val_valence_output_mae: 0.8291 - val_arousal_output_mae: 0.3973 - val_dominance_output_mae: 0.4968
# Epoch 19/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7576 - valence_output_loss: 0.2400 - arousal_output_loss: 0.4077 - dominance_output_loss: 0.1099 - valence_output_mae: 0.3819 - arousal_output_mae: 0.4554 - dominance_output_mae: 0.2532
# Epoch 00019: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 375s 206ms/step - loss: 0.7576 - valence_output_loss: 0.2400 - arousal_output_loss: 0.4077 - dominance_output_loss: 0.1099 - valence_output_mae: 0.3819 - arousal_output_mae: 0.4554 - dominance_output_mae: 0.2532 - val_loss: 1.8390 - val_valence_output_loss: 1.1128 - val_arousal_output_loss: 0.3014 - val_dominance_output_loss: 0.4248 - val_valence_output_mae: 0.8295 - val_arousal_output_mae: 0.4015 - val_dominance_output_mae: 0.4962
# Epoch 20/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7419 - valence_output_loss: 0.2294 - arousal_output_loss: 0.4062 - dominance_output_loss: 0.1062 - valence_output_mae: 0.3736 - arousal_output_mae: 0.4544 - dominance_output_mae: 0.2491
# Epoch 00020: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 371s 204ms/step - loss: 0.7419 - valence_output_loss: 0.2294 - arousal_output_loss: 0.4062 - dominance_output_loss: 0.1062 - valence_output_mae: 0.3736 - arousal_output_mae: 0.4544 - dominance_output_mae: 0.2491 - val_loss: 1.8368 - val_valence_output_loss: 1.1139 - val_arousal_output_loss: 0.2996 - val_dominance_output_loss: 0.4232 - val_valence_output_mae: 0.8312 - val_arousal_output_mae: 0.3985 - val_dominance_output_mae: 0.4973
# Epoch 21/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7262 - valence_output_loss: 0.2172 - arousal_output_loss: 0.4038 - dominance_output_loss: 0.1052 - valence_output_mae: 0.3636 - arousal_output_mae: 0.4524 - dominance_output_mae: 0.2479
# Epoch 00021: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 380s 209ms/step - loss: 0.7262 - valence_output_loss: 0.2172 - arousal_output_loss: 0.4038 - dominance_output_loss: 0.1052 - valence_output_mae: 0.3636 - arousal_output_mae: 0.4524 - dominance_output_mae: 0.2479 - val_loss: 1.8641 - val_valence_output_loss: 1.1305 - val_arousal_output_loss: 0.2987 - val_dominance_output_loss: 0.4349 - val_valence_output_mae: 0.8358 - val_arousal_output_mae: 0.3967 - val_dominance_output_mae: 0.5017
# Epoch 22/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7157 - valence_output_loss: 0.2117 - arousal_output_loss: 0.4006 - dominance_output_loss: 0.1034 - valence_output_mae: 0.3590 - arousal_output_mae: 0.4507 - dominance_output_mae: 0.2453
# Epoch 00022: val_loss did not improve from 1.69112
# 1818/1817 [==============================] - 378s 208ms/step - loss: 0.7157 - valence_output_loss: 0.2117 - arousal_output_loss: 0.4006 - dominance_output_loss: 0.1034 - valence_output_mae: 0.3590 - arousal_output_mae: 0.4507 - dominance_output_mae: 0.2453 - val_loss: 1.8099 - val_valence_output_loss: 1.1001 - val_arousal_output_loss: 0.2965 - val_dominance_output_loss: 0.4134 - val_valence_output_mae: 0.8235 - val_arousal_output_mae: 0.3934 - val_dominance_output_mae: 0.4903
# Epoch 23/1000
#  233/1817 [==>...........................] - ETA: 4:44 - loss: 0.7257 - valence_output_loss: 0.2071 - arousal_output_loss: 0.4144 - dominance_output_loss: 0.1042 - valence_output_mae: 0.3548 - arousal_output_mae: 0.4535 - dominance_output_mae: 0.2433
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-5b88b95659bd> in <module>()
# ----> 1 history = model.fit(gen_train, epochs=1000, steps_per_epoch=trainidx/batch_size, validation_data=gen_valid, validation_steps=valididx/batch_size, callbacks=callbacks, batch_size=32)
#       2
#       3 def plot_train_history(history):
#       4     fig, axes = plt.subplots(1, 4, figsize=(20, 5))
#       5     axes[0].plot(history.history['dominance_output_mae'], label='Dominance Train MAE')
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_function(iterator)
#     804       def train_function(iterator):
#     805         """Runs a training execution with one step."""
# --> 806         return step_function(self, iterator)
#     807
#     808     else:
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in step_function(model, iterator)
#     794
#     795       data = next(iterator)
# --> 796       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     797       outputs = reduce_per_replica(
#     798           outputs, self.distribute_strategy, reduction='first')
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1209       fn = autograph.tf_convert(
#    1210           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1211       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1212
#    1213   # TODO(b/151224785): Remove deprecated alias.
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2583       kwargs = {}
#    2584     with self._container_strategy().scope():
# -> 2585       return self._call_for_each_replica(fn, args, kwargs)
#    2586
#    2587   def _call_for_each_replica(self, fn, args, kwargs):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2943         self._container_strategy(),
#    2944         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2945       return fn(*args, **kwargs)
#    2946
#    2947   def _reduce_to(self, reduce_op, value, destinations, experimental_hints):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     273   def wrapper(*args, **kwargs):
#     274     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 275       return func(*args, **kwargs)
#     276
#     277   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in run_step(data)
#     787
#     788       def run_step(data):
# --> 789         outputs = model.train_step(data)
#     790         # Ensure counter is updated only if `train_step` succeeds.
#     791         with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_step(self, data)
#     757               self.trainable_variables)
#     758
# --> 759     self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     760     return {m.name: m.result() for m in self.metrics}
#     761
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/compile_utils.py in update_state(self, y_true, y_pred, sample_weight)
#     407         if metric_obj is None:
#     408           continue
# --> 409         metric_obj.update_state(y_t, y_p, sample_weight=mask)
#     410
#     411       for weighted_metric_obj in weighted_metric_objs:
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/utils/metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      88
#      89     with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 90       update_op = update_state_fn(*args, **kwargs)
#      91     if update_op is not None:  # update_op will be None in eager execution.
#      92       metric_obj.add_update(update_op)
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/metrics.py in update_state_fn(*args, **kwargs)
#     174         control_status = ag_ctx.control_status_ctx()
#     175         ag_update_state = autograph.tf_convert(obj_update_state, control_status)
# --> 176         return ag_update_state(*args, **kwargs)
#     177     else:
#     178       if isinstance(obj.update_state, def_function.Function):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     253       try:
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#     257         if hasattr(e, 'ag_error_metadata'):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     455   if conversion.is_in_whitelist_cache(f, options):
#     456     logging.log(2, 'Whitelisted %s: from cache', f)
# --> 457     return _call_unconverted(f, args, kwargs, options, False)
#     458
#     459   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#     341
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/metrics.py in update_state(self, y_true, y_pred, sample_weight)
#     612     matches = ag_fn(y_true, y_pred, **self._fn_kwargs)
#     613     return super(MeanMetricWrapper, self).update_state(
# --> 614         matches, sample_weight=sample_weight)
#     615
#     616   def get_config(self):
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/metrics.py in update_state(self, values, sample_weight)
#     382     elif self.reduction == metrics_utils.Reduction.WEIGHTED_MEAN:
#     383       if sample_weight is None:
# --> 384         num_values = math_ops.cast(array_ops.size(values), self._dtype)
#     385       else:
#     386         num_values = math_ops.reduce_sum(sample_weight)
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     920       x = ops.convert_to_tensor(x, name="x")
#     921       if x.dtype.base_dtype != base_type:
# --> 922         x = gen_math_ops.cast(x, base_type, name=name)
#     923     if x.dtype.is_complex and base_type.is_floating:
#     924       logging.warn("Casting complex to real discards imaginary part.")
#
# /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in cast(x, DstT, Truncate, name)
#    1853       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1854         _ctx._context_handle, tld.device_name, "Cast", name, tld.op_callbacks,
# -> 1855         x, "DstT", DstT, "Truncate", Truncate)
#    1856       return _result
#    1857     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Best validation loss: 1.69112
