# %% [markdown]
# ## ResNet 50

# %%
# !pip install vit-keras
# Out:
# Collecting vit-keras
#   Downloading vit_keras-0.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /home/workstation/anaconda3/lib/python3.6/site-packages (from vit-keras) (1.3.0)
# Collecting validators
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: numpy>=1.13.3 in /home/workstation/anaconda3/lib/python3.6/site-packages (from scipy->vit-keras) (1.19.5)
# Requirement already satisfied: decorator>=3.4.0 in /home/workstation/.local/lib/python3.6/site-packages (from validators->vit-keras) (4.3.0)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19567 sha256=8f34420a349b3e4a45cc69a4c3537d115b76d0235fa4feeab9e47c6fdc023184
#   Stored in directory: /home/workstation/.cache/pip/wheels/c6/eb/0c/fc63cc3975728b21fd16b398f94d2b002774e7e5c22cf11c76
# Successfully built validators
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.20.0 vit-keras-0.1.0

# %%
###### check gpu
import tensorflow as tf
from tensorflow.python.client import device_lib
import pandas as pd
import numpy as np
import glob
import random
import locale
from PIL import Image
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow import keras
#import tensorflow_addons as tfa
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4
from tensorflow.keras import layers, models, Model, Input
from tensorflow.keras.layers import concatenate, Input, Dense, Flatten, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint, History
from tensorflow.keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError, MeanSquaredError
from tensorflow.keras.utils import plot_model

from keras.layers.convolutional import Conv2D,MaxPooling2D
from keras.layers.core import Activation,Dropout,Dense
from tensorflow.keras.optimizers import Adam

import string
from keras.preprocessing import image as krs_image

# feature selection libraries
from sklearn.feature_selection import RFE

# %%
color_gt = ['RGB-R', 'RGB-G','RGB-B','HSL-H','HSL-S','HSL-L']
object_gt = ['aeroplane','apple','backpack','banana','baseball bat','baseball glove','bear','bed','bench','bicycle',
'bird','boat','book','bottle','bowl','broccoli','bus','cake','car','carrot','cat','cell phone','chair',
'clock','cow','cup','diningtable','dog','donut','elephant','fire hydrant','fork','frisbee','giraffe',
'handbag','horse','hot dog','keyboard','kite','knife','laptop','microwave','motorbike','mouse','orange',
'oven','parking meter','person','pizza','pottedplant','refrigerator','remote','sandwich','scissors','sheep',
'sink','skateboard','skis','snowboard','sofa','spoon','sports ball','stop sign','suitcase','surfboard',
'teddy bear','tennis racket','tie','toilet','toothbrush','traffic light','train','truck','tvmonitor','umbrella',
'vase','wine glass','zebra']
scene_gt = ['Indoor/Outdoor','shopping and dining','workplace (office building, factory, lab, etc.)',
'home or hotel','transportation (vehicle interiors, stations, etc.)','sports and leisure','cultural (art, education, religion, millitary, law, politics, etc.)',
'water, ice, snow','mountains, hills, desert, sky','forest, field, jungle','man-made elements','transportation (roads, parking, bridges, boats, airports, etc.)',
'cultural or historical building/place (millitary, religious)','sports fields, parks, leisure spaces','industrial and construction','houses, cabins, gardens, and farms',
'commercial buildings, shops, markets, cities, and towns','airfield','airplane_cabin','airport_terminal','alcove','alley','amphitheater','amusement_arcade',
'amusement_park','apartment_building/outdoor','aquarium','aqueduct','arcade','arch','archaelogical_excavation','archive','arena/hockey','arena/performance',
'arena/rodeo','army_base','art_gallery','art_school','art_studio','artists_loft','assembly_line','athletic_field/outdoor','atrium/public','attic','auditorium',
'auto_factory','auto_showroom','badlands','bakery/shop','balcony/exterior','balcony/interior','ball_pit','ballroom','bamboo_forest','bank_vault','banquet_hall',
'bar','barn','barndoor','baseball_field','basement','basketball_court/indoor','bathroom','bazaar/indoor','bazaar/outdoor','beach','beach_house','beauty_salon',
'bedchamber','bedroom','beer_garden','beer_hall','berth','biology_laboratory','boardwalk','boat_deck','boathouse','bookstore','booth/indoor','botanical_garden',
'bow_window/indoor','bowling_alley','boxing_ring','bridge','bullring','burial_chamber','bus_interior','bus_station/indoor','butchers_shop','butte','cabin/outdoor',
'campsite','campus','canal/natural','canal/urban','candy_store','canyon','car_interior','carrousel','castle','catacomb','cemetery','chalet','chemistry_lab',
'childs_room','church/indoor','church/outdoor','classroom','clean_room','cliff','closet','clothing_store','coast','cockpit','coffee_shop','computer_room',
'conference_center','conference_room','construction_site','corn_field','corral','corridor','cottage','courthouse','courtyard','creek','crevasse','crosswalk',
'dam','delicatessen','department_store','desert/sand','desert/vegetation','desert_road','diner/outdoor','dining_hall','dining_room','discotheque','doorway/outdoor',
'dorm_room','downtown','dressing_room','driveway','drugstore','elevator/door','elevator_lobby','elevator_shaft','embassy','engine_room','entrance_hall',
'escalator/indoor','excavation','fabric_store','farm','fastfood_restaurant','field/cultivated','field/wild','field_road','fire_escape','fire_station','fishpond',
'flea_market/indoor','florist_shop/indoor','food_court','football_field','forest/broadleaf','forest_path','forest_road','formal_garden','fountain','galley',
'garage/indoor','garage/outdoor','gas_station','gazebo/exterior','general_store/indoor','general_store/outdoor','gift_shop','glacier','golf_course','greenhouse/indoor',
'greenhouse/outdoor','grotto','gymnasium/indoor','hangar/indoor','hangar/outdoor','harbor','hardware_store','hayfield','heliport','highway','home_office',
'home_theater','hospital','hospital_room','hot_spring','hotel/outdoor','hotel_room','house','hunting_lodge/outdoor','ice_cream_parlor','ice_floe','ice_shelf',
'ice_skating_rink/indoor','ice_skating_rink/outdoor','iceberg','igloo','industrial_area','inn/outdoor','islet','jacuzzi/indoor','jail_cell','japanese_garden',
'jewelry_shop','junkyard','kasbah','kennel/outdoor','kindergarden_classroom','kitchen','lagoon','lake/natural','landfill','landing_deck','laundromat','lawn',
'lecture_room','legislative_chamber','library/indoor','library/outdoor','lighthouse','living_room','loading_dock','lobby','lock_chamber','locker_room','mansion',
'manufactured_home','market/indoor','market/outdoor','marsh','martial_arts_gym','mausoleum','medina','mezzanine','moat/water','mosque/outdoor','motel','mountain',
'mountain_path','mountain_snowy','movie_theater/indoor','museum/indoor','museum/outdoor','music_studio','natural_history_museum','nursery','nursing_home','oast_house',
'ocean','office','office_building','office_cubicles','oilrig','operating_room','orchard','orchestra_pit','pagoda','palace','pantry','park','parking_garage/indoor',
'parking_garage/outdoor','parking_lot','pasture','patio','pavilion','pet_shop','pharmacy','phone_booth','physics_laboratory','picnic_area','pier','pizzeria','playground',
'playroom','plaza','pond','porch','promenade','pub/indoor','racecourse','raceway','raft','railroad_track','rainforest','reception','recreation_room','repair_shop',
'residential_neighborhood','restaurant','restaurant_kitchen','restaurant_patio','rice_paddy','river','rock_arch','roof_garden','rope_bridge','ruin','runway','sandbox',
'sauna','schoolhouse','science_museum','server_room','shed','shoe_shop','shopfront','shopping_mall/indoor','shower','ski_resort','ski_slope','sky','skyscraper','slum',
'snowfield','soccer_field','stable','stadium/baseball','stadium/football','stadium/soccer','stage/indoor','stage/outdoor','staircase','storage_room','street',
'subway_station/platform','supermarket','sushi_bar','swamp','swimming_hole','swimming_pool/indoor','swimming_pool/outdoor','synagogue/outdoor','television_room',
'television_studio','temple/asia','throne_room','ticket_booth','topiary_garden','tower','toyshop','train_interior','train_station/platform','tree_farm','tree_house',
'trench','tundra','underwater/ocean_deep','utility_room','valley','vegetable_garden','veterinarians_office','viaduct','village','vineyard','volcano',
'volleyball_court/outdoor','waiting_room','water_park','water_tower','waterfall','watering_hole','wave','wet_bar','wheat_field','wind_farm','windmill','yard',
'youth_hostel','zen_garden']

# %%
# image features data in csv
train_x_data = pd.read_csv('../../data/train_x_rounded.csv', index_col ='iid')
test_x_data = pd.read_csv('../../data/test_x_rounded.csv',index_col ="iid")
valid_x_data = pd.read_csv('../../data/valid_x_rounded.csv',index_col ="iid")

# rejected_features = color_gt + scene_gt + ['boat', 'car_interior', 'forest, field, jungle', 'forest/broadleaf']
rejected_features = color_gt

train_x_data.drop(columns=rejected_features,inplace=True)
test_x_data.drop(columns=rejected_features,inplace=True)
valid_x_data.drop(columns=rejected_features,inplace=True)

trainAttrX = train_x_data

train_y_data = pd.read_csv('../../data/train_y.csv', index_col ='iid')
test_y_data = pd.read_csv('../../data/test_y.csv',index_col ="iid")
valid_y_data = pd.read_csv('../../data/valid_y.csv',index_col ="iid")

# %%
train_x_data
# Out:
#                 aeroplane  apple  backpack  banana  baseball bat  \
# iid
# I000259252.jpg          0      0         0       0             0
# I000296556.jpg          0      0         0       0             0
# I000193784.jpg          0      0         0       0             0
# I000793950.jpg          0      0         0       0             0
# I000872207.jpg          0      0         0       0             0
# I000583119.jpg          0      0         0       0             0
# I000981321.jpg          0      0         0       0             0
# I000149626.jpg          0      0         0       0             0
# I000833174.jpg          0      0         0       0             0
# I000257061.jpg          0      0         0       0             0
# I000765049.jpg          0      0         0       0             0
# I000918213.jpg          0      0         0       0             0
# I000394665.jpg          0      0         0       0             0
# I000671761.jpg          0      0         0       0             0
# I000273589.jpg          0      0         0       0             0
# I000442834.jpg          0      0         0       0             0
# I000002428.jpg          0      0         0       0             0
# I000313373.jpg          0      0         0       0             0
# I000142320.jpg          0      0         0       0             0
# I000656837.jpg          0      0         0       0             0
# I000677944.jpg          0      0         0       0             0
# I000096584.jpg          0      0         0       0             0
# I000099275.jpg          0      0         0       0             0
# I000574471.jpg          0      0         0       0             0
# I000217656.jpg          0      0         0       0             0
# I000746435.jpg          0      0         0       0             0
# I000477050.jpg          0      0         0       0             0
# I000668363.jpg          0      0         0       0             0
# I000418686.jpg          0      0         0       0             0
# I000300685.jpg          0      0         0       0             0
# ...                   ...    ...       ...     ...           ...
# I000703953.jpg          0      0         0       0             0
# I000830059.jpg          0      0         0       0             0
# I000432751.jpg          0      0         0       0             0
# I000811276.jpg          0      0         0       0             0
# I000731162.jpg          0      0         0       0             0
# I000042554.jpg          0      0         0       0             0
# I000245125.jpg          0      0         0       0             0
# I000326269.jpg          0      0         0       0             0
# I000883965.jpg          0      0         0       0             0
# I000359203.jpg          0      0         0       0             0
# I000669900.jpg          0      0         0       0             0
# I000072767.jpg          0      0         0       0             0
# I000836046.jpg          0      0         0       0             0
# I000799217.jpg          0      0         0       0             0
# I000777459.jpg          0      0         0       0             0
# I000737348.jpg          0      0         0       0             0
# I000011687.jpg          0      0         0       0             0
# I000798245.jpg          0      0         0       0             0
# I000828421.jpg          0      0         0       0             0
# I000487257.jpg          0      0         0       0             0
# I000214889.jpg          0      0         0       0             0
# I000743187.jpg          0      0         0       0             0
# I000520822.jpg          0      0         0       0             0
# I000447722.jpg          0      0         0       0             0
# I001005806.jpg          0      0         0       0             0
# I000087134.jpg          0      0         0       0             0
# I000681198.jpg          0      0         0       0             0
# I000942624.jpg          0      0         0       0             0
# I000013459.jpg          0      0         0       0             0
# I000212886.jpg          0      0         0       0             0
#
#                 baseball glove  bear  bed  bench  bicycle  ...  waterfall  \
# iid                                                        ...
# I000259252.jpg               0     0    0      0        0  ...          0
# I000296556.jpg               0     0    0      0        0  ...          0
# I000193784.jpg               0     0    0      0        0  ...          0
# I000793950.jpg               0     0    0      0        0  ...          0
# I000872207.jpg               0     1    0      0        0  ...          0
# I000583119.jpg               0     0    0      0        0  ...          0
# I000981321.jpg               0     0    0      0        0  ...          0
# I000149626.jpg               0     0    0      0        0  ...          0
# I000833174.jpg               0     0    0      0        0  ...          0
# I000257061.jpg               0     0    0      0        0  ...          0
# I000765049.jpg               0     0    0      0        0  ...          0
# I000918213.jpg               0     0    0      0        0  ...          0
# I000394665.jpg               0     1    0      0        0  ...          0
# I000671761.jpg               0     0    0      0        0  ...          0
# I000273589.jpg               0     0    0      0        0  ...          0
# I000442834.jpg               0     0    0      0        0  ...          0
# I000002428.jpg               0     0    0      0        0  ...          0
# I000313373.jpg               0     0    0      0        0  ...          0
# I000142320.jpg               0     0    0      0        0  ...          0
# I000656837.jpg               0     0    0      0        0  ...          0
# I000677944.jpg               0     0    0      0        0  ...          0
# I000096584.jpg               0     0    0      0        0  ...          0
# I000099275.jpg               0     0    0      0        0  ...          0
# I000574471.jpg               0     0    0      0        0  ...          0
# I000217656.jpg               0     0    0      0        0  ...          0
# I000746435.jpg               0     0    0      0        0  ...          0
# I000477050.jpg               0     0    0      0        0  ...          0
# I000668363.jpg               0     0    0      0        0  ...          0
# I000418686.jpg               0     0    0      0        0  ...          0
# I000300685.jpg               0     0    0      0        0  ...          0
# ...                        ...   ...  ...    ...      ...  ...        ...
# I000703953.jpg               0     0    0      0        0  ...          0
# I000830059.jpg               0     0    0      0        0  ...          0
# I000432751.jpg               0     0    0      0        0  ...          0
# I000811276.jpg               0     0    0      0        0  ...          0
# I000731162.jpg               0     0    0      0        0  ...          0
# I000042554.jpg               0     0    0      0        0  ...          0
# I000245125.jpg               0     0    0      0        0  ...          0
# I000326269.jpg               0     0    0      0        0  ...          0
# I000883965.jpg               0     0    0      0        0  ...          0
# I000359203.jpg               0     0    0      0        0  ...          0
# I000669900.jpg               0     0    0      0        0  ...          0
# I000072767.jpg               0     0    0      0        0  ...          0
# I000836046.jpg               0     0    0      0        0  ...          0
# I000799217.jpg               0     0    1      0        0  ...          0
# I000777459.jpg               0     0    0      0        0  ...          0
# I000737348.jpg               0     0    0      0        0  ...          0
# I000011687.jpg               0     0    0      0        0  ...          0
# I000798245.jpg               0     0    0      0        0  ...          0
# I000828421.jpg               0     0    0      0        0  ...          0
# I000487257.jpg               0     0    0      0        0  ...          0
# I000214889.jpg               0     0    0      0        0  ...          0
# I000743187.jpg               0     0    0      0        0  ...          0
# I000520822.jpg               0     0    0      0        0  ...          0
# I000447722.jpg               0     0    0      0        0  ...          0
# I001005806.jpg               0     0    0      0        0  ...          0
# I000087134.jpg               0     0    0      0        0  ...          0
# I000681198.jpg               0     0    0      0        0  ...          0
# I000942624.jpg               0     0    0      0        0  ...          0
# I000013459.jpg               0     0    0      0        0  ...          0
# I000212886.jpg               0     0    0      0        0  ...          0
#
#                 watering_hole  wave  wet_bar  wheat_field  wind_farm  \
# iid
# I000259252.jpg              0     0        0            0          0
# I000296556.jpg              0     0        0            0          0
# I000193784.jpg              0     0        0            0          0
# I000793950.jpg              0     0        0            0          0
# I000872207.jpg              0     0        0            0          0
# I000583119.jpg              0     0        0            0          0
# I000981321.jpg              0     0        0            0          0
# I000149626.jpg              0     0        0            0          0
# I000833174.jpg              0     0        0            0          0
# I000257061.jpg              0     0        0            0          0
# I000765049.jpg              0     0        0            0          0
# I000918213.jpg              0     0        0            0          0
# I000394665.jpg              0     0        0            0          0
# I000671761.jpg              0     0        0            0          0
# I000273589.jpg              0     0        0            0          0
# I000442834.jpg              0     0        0            0          0
# I000002428.jpg              0     0        0            0          0
# I000313373.jpg              0     0        0            0          0
# I000142320.jpg              0     0        0            0          0
# I000656837.jpg              0     0        0            0          0
# I000677944.jpg              0     0        0            0          0
# I000096584.jpg              0     0        0            0          0
# I000099275.jpg              0     0        0            0          0
# I000574471.jpg              0     0        0            0          0
# I000217656.jpg              0     0        0            0          0
# I000746435.jpg              0     0        0            0          0
# I000477050.jpg              0     0        0            0          0
# I000668363.jpg              0     0        0            0          0
# I000418686.jpg              0     0        0            0          0
# I000300685.jpg              0     0        0            0          0
# ...                       ...   ...      ...          ...        ...
# I000703953.jpg              0     0        0            0          0
# I000830059.jpg              0     0        0            0          0
# I000432751.jpg              0     0        0            0          0
# I000811276.jpg              0     0        0            0          0
# I000731162.jpg              0     0        0            0          0
# I000042554.jpg              0     0        0            0          0
# I000245125.jpg              0     0        0            0          0
# I000326269.jpg              0     0        0            0          0
# I000883965.jpg              0     0        0            0          0
# I000359203.jpg              0     0        0            0          0
# I000669900.jpg              0     0        0            0          0
# I000072767.jpg              0     0        0            0          0
# I000836046.jpg              0     0        0            0          0
# I000799217.jpg              0     0        0            0          0
# I000777459.jpg              0     0        0            0          0
# I000737348.jpg              0     0        0            0          0
# I000011687.jpg              0     0        0            0          0
# I000798245.jpg              0     0        0            0          0
# I000828421.jpg              0     0        0            0          0
# I000487257.jpg              0     0        0            0          0
# I000214889.jpg              0     0        0            0          0
# I000743187.jpg              0     0        0            0          0
# I000520822.jpg              0     0        0            0          0
# I000447722.jpg              0     0        0            0          0
# I001005806.jpg              0     0        0            0          0
# I000087134.jpg              0     0        0            0          0
# I000681198.jpg              0     0        0            0          0
# I000942624.jpg              0     0        0            0          0
# I000013459.jpg              0     0        0            0          0
# I000212886.jpg              0     0        0            0          0
#
#                 windmill  yard  youth_hostel  zen_garden
# iid
# I000259252.jpg         0     0             0           0
# I000296556.jpg         0     0             0           0
# I000193784.jpg         0     0             0           0
# I000793950.jpg         0     0             0           0
# I000872207.jpg         0     0             0           0
# I000583119.jpg         0     0             0           0
# I000981321.jpg         0     0             0           0
# I000149626.jpg         0     0             0           0
# I000833174.jpg         0     0             0           0
# I000257061.jpg         0     0             0           0
# I000765049.jpg         0     0             0           0
# I000918213.jpg         0     0             0           0
# I000394665.jpg         0     0             0           0
# I000671761.jpg         0     0             0           0
# I000273589.jpg         0     0             0           0
# I000442834.jpg         0     0             0           0
# I000002428.jpg         0     0             0           0
# I000313373.jpg         0     0             0           0
# I000142320.jpg         0     0             0           0
# I000656837.jpg         0     0             0           0
# I000677944.jpg         0     0             0           0
# I000096584.jpg         0     0             0           0
# I000099275.jpg         0     0             0           0
# I000574471.jpg         0     0             0           0
# I000217656.jpg         0     0             0           0
# I000746435.jpg         0     0             0           0
# I000477050.jpg         0     0             0           0
# I000668363.jpg         0     0             0           0
# I000418686.jpg         0     0             0           0
# I000300685.jpg         0     0             0           0
# ...                  ...   ...           ...         ...
# I000703953.jpg         0     0             0           0
# I000830059.jpg         0     0             0           0
# I000432751.jpg         0     0             0           0
# I000811276.jpg         0     0             0           0
# I000731162.jpg         0     0             0           0
# I000042554.jpg         0     0             0           0
# I000245125.jpg         0     0             0           0
# I000326269.jpg         0     0             0           0
# I000883965.jpg         0     0             0           0
# I000359203.jpg         0     0             0           0
# I000669900.jpg         0     0             0           0
# I000072767.jpg         0     0             0           0
# I000836046.jpg         0     0             0           0
# I000799217.jpg         0     0             0           0
# I000777459.jpg         0     0             0           0
# I000737348.jpg         0     0             0           0
# I000011687.jpg         0     0             0           0
# I000798245.jpg         0     0             0           0
# I000828421.jpg         0     0             0           0
# I000487257.jpg         0     0             0           0
# I000214889.jpg         0     0             0           0
# I000743187.jpg         0     0             0           0
# I000520822.jpg         0     0             0           0
# I000447722.jpg         0     0             0           0
# I001005806.jpg         0     0             0           0
# I000087134.jpg         0     0             0           0
# I000681198.jpg         0     0             0           0
# I000942624.jpg         0     0             0           0
# I000013459.jpg         0     0             0           0
# I000212886.jpg         0     0             0           0
#
# [58174 rows x 458 columns]

# %% [markdown]
# ### With Images

# %%
# image data 
train_file_list = glob.glob('../../train/*.jpg', recursive = True)
random.shuffle(train_file_list)

test_file_list = glob.glob('../../test/*.jpg', recursive = True)
random.shuffle(test_file_list)

valid_file_list = glob.glob('../../valid/*.jpg', recursive = True)
random.shuffle(valid_file_list)

# %%
train_file_list = [x for x in train_file_list if "(1)" not in x]

# %%
test_file_list = [x for x in test_file_list if "(1)" not in x]

# %%
valid_file_list = [x for x in valid_file_list if "(1)" not in x]

# %%
len(train_file_list)
# Out:
# 58174

# %%
len(test_file_list)
# Out:
# 12467

# %%
len(valid_file_list)
# Out:
# 12466

# %%
# data generator

# Create the arguments for image preprocessing
data_gen_args = dict(
    horizontal_flip=True,
    brightness_range=[0.5, 1.5],
    shear_range=10,
    channel_shift_range=50,
    rescale=1. / 255,
)

# Create an empty data generator
datagen = ImageDataGenerator()

def my_gen(images_list, dataframe, df_y, batch_size):
    i = 0
    while True:
        batch = {'img_input': [], 'csv_input': [], 'valence': [], 'arousal': [], 'dominance': []}
        for b in range(batch_size):
            if i == len(images_list):
                i = 0
                random.shuffle(images_list)
            # Read image from list and convert to array
            image_path = images_list[i]
            image_name = os.path.basename(image_path).replace('.JPG', '')
            #image = tf.keras.utils.load_img(image_path, target_size=(224, 224)) 
            image = krs_image.load_img(image_path, target_size=(224, 224)) #image height & width
            image = datagen.apply_transform(image, data_gen_args)
            image = krs_image.img_to_array(image)
            #image = tf.keras.utils.img_to_array(image)

            # Read data from csv using the name of current image
            csv_features = dataframe.loc[image_name, :]
            y = df_y.loc[image_name, :]
            val_train = y[0]
            aro_train = y[1]
            dom_train = y[2]

            #print(image_name)
            batch['img_input'].append(image)
            batch['csv_input'].append(csv_features)
            batch['valence'].append(val_train)
            batch['arousal'].append(aro_train)
            batch['dominance'].append(dom_train)

            i += 1

        batch['img_input'] = np.array(batch['img_input'])
        batch['csv_input'] = np.array(batch['csv_input'])
        batch['valence'] = np.array(batch['valence'])
        batch['arousal'] = np.array(batch['arousal'])
        batch['dominance'] = np.array(batch['dominance'])
        

        yield [batch['img_input']], [batch['valence'],batch['arousal'],batch['dominance']]

gen_train = my_gen(train_file_list, train_x_data, train_y_data, 32)
gen_test = my_gen(test_file_list, test_x_data, test_y_data, 32)
gen_valid = my_gen(valid_file_list, valid_x_data, valid_y_data, 32)

# %%
def create_mlp(dim):
	# define our MLP network
	model = Sequential()
	model.add(Dense(512, input_dim=dim, activation="relu", name='csv'))
	model.add(Dense(256, activation="relu"))
	model.add(Dense(128, activation="relu"))
	model.add(Dense(64, activation="relu"))    
    
	return model

# %%
from tensorflow.keras.applications.resnet import ResNet50

def create_resnet(width, height, depth):
    # inputs= Input(shape=(width, height, depth), name='img_input')  

    res = ResNet50(
        weights='imagenet',  
        include_top=False,  
        input_shape = (width, height, depth),  
    )

    for layer in res.layers:  
        layer.trainable = False #false: freeze, true:train by own

    x = layers.BatchNormalization()(res.output)
    top_dropout_rate = 0.4
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    x = layers.Flatten()(x)

    model = Model(res.input, x, name="ResNet")
    return model

# %%
resnet = create_resnet(224, 224, 3)
resnet.summary()
# Out:
# conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# top_dropout (Dropout)           (None, 7, 7, 2048)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100352)       0           top_dropout[0][0]
# ==================================================================================================
# Total params: 23,595,904
# Trainable params: 4,096
# Non-trainable params: 23,591,808
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# x = Dense(1024, activation="relu",name='csv_img')(resnet.output)
x = Dense(512, activation="relu")(resnet.output)

valence_output = Dense(units=1, activation='linear', name='valence_output')(x)
arousal_output = Dense(units=1, activation='linear', name='arousal_output')(x)
dominance_output = Dense(units=1, activation='linear', name='dominance_output')(x)

model = Model(inputs=[resnet.input], outputs=[valence_output, arousal_output, dominance_output])

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt, run_eagerly=True,
              loss={'valence_output': 'mse', 'arousal_output': 'mse', 'dominance_output': 'mse'},
              metrics={'valence_output': 'mae', 'arousal_output': 'mae', 'dominance_output': 'mae'})

# %%
model.summary()
# Out:
# [0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# top_dropout (Dropout)           (None, 7, 7, 2048)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100352)       0           top_dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          51380736    flatten_1[0][0]
# __________________________________________________________________________________________________
# valence_output (Dense)          (None, 1)            513         dense[0][0]
# __________________________________________________________________________________________________
# arousal_output (Dense)          (None, 1)            513         dense[0][0]
# __________________________________________________________________________________________________
# dominance_output (Dense)        (None, 1)            513         dense[0][0]
# ==================================================================================================
# Total params: 74,978,179
# Trainable params: 51,386,371
# Non-trainable params: 23,591,808
# __________________________________________________________________________________________________

# %%
import tensorflow

filename='./metric_logs/resnet-04-dropout-log.csv'
history_logger = tensorflow.keras.callbacks.CSVLogger(filename, separator=",", append=True)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, mode='min', min_delta=0.0001),
    ModelCheckpoint('./trained_models/Resnet-04-dropout', monitor='val_loss', verbose=1, save_best_only=True, mode='min'),
    history_logger
]

batch_size = 32
trainidx = len(train_file_list)
testidx = len(test_file_list)
valididx = len(valid_file_list)

# %%
history = model.fit(gen_train, epochs=1000, steps_per_epoch=trainidx/batch_size, validation_data=gen_valid, validation_steps=valididx/batch_size, callbacks=callbacks, batch_size=32)

def plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['dominance_output_mae'], label='Dominance Train MAE')
    axes[0].plot(history.history['val_dominance_output_mae'], label='Dominance Val MAE')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()

    axes[1].plot(history.history['arousal_output_mae'], label='Arousal Train MAE')
    axes[1].plot(history.history['val_arousal_output_mae'], label='Arousal Val MAE')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['valence_output_mae'], label='Valence Train MAE')
    axes[2].plot(history.history['val_valence_output_mae'], label='Valence Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

model.save('b4_mixedinput_fc_1024_512.h5')
# Out:
# Epoch 1/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 68.6500 - valence_output_loss: 41.8150 - arousal_output_loss: 15.1616 - dominance_output_loss: 11.6735 - valence_output_mae: 0.9461 - arousal_output_mae: 0.5591 - dominance_output_mae: 0.6120
# Epoch 00001: val_loss improved from inf to 2.49463, saving model to ./trained_models/Resnet-04-dropout
# WARNING:tensorflow:From /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/workstation/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout/assets
# 1818/1817 [==============================] - 498s 274ms/step - loss: 68.6500 - valence_output_loss: 41.8150 - arousal_output_loss: 15.1616 - dominance_output_loss: 11.6735 - valence_output_mae: 0.9461 - arousal_output_mae: 0.5591 - dominance_output_mae: 0.6120 - val_loss: 2.4946 - val_valence_output_loss: 1.2973 - val_arousal_output_loss: 0.5176 - val_dominance_output_loss: 0.6797 - val_valence_output_mae: 0.8292 - val_arousal_output_mae: 0.4334 - val_dominance_output_mae: 0.5131
# Epoch 2/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 37.9178 - valence_output_loss: 6.7905 - arousal_output_loss: 20.7899 - dominance_output_loss: 10.3374 - valence_output_mae: 0.8487 - arousal_output_mae: 0.5669 - dominance_output_mae: 0.5811
# Epoch 00002: val_loss improved from 2.49463 to 2.06012, saving model to ./trained_models/Resnet-04-dropout
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout/assets
# 1818/1817 [==============================] - 501s 275ms/step - loss: 37.9178 - valence_output_loss: 6.7905 - arousal_output_loss: 20.7899 - dominance_output_loss: 10.3374 - valence_output_mae: 0.8487 - arousal_output_mae: 0.5669 - dominance_output_mae: 0.5811 - val_loss: 2.0601 - val_valence_output_loss: 1.1458 - val_arousal_output_loss: 0.4082 - val_dominance_output_loss: 0.5062 - val_valence_output_mae: 0.8405 - val_arousal_output_mae: 0.4660 - val_dominance_output_mae: 0.5482
# Epoch 3/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 165.5817 - valence_output_loss: 23.5819 - arousal_output_loss: 76.1840 - dominance_output_loss: 65.8157 - valence_output_mae: 0.8202 - arousal_output_mae: 0.5131 - dominance_output_mae: 0.5269
# Epoch 00003: val_loss improved from 2.06012 to 1.77406, saving model to ./trained_models/Resnet-04-dropout
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout/assets
# 1818/1817 [==============================] - 501s 276ms/step - loss: 165.5817 - valence_output_loss: 23.5819 - arousal_output_loss: 76.1840 - dominance_output_loss: 65.8157 - valence_output_mae: 0.8202 - arousal_output_mae: 0.5131 - dominance_output_mae: 0.5269 - val_loss: 1.7741 - val_valence_output_loss: 1.0310 - val_arousal_output_loss: 0.3235 - val_dominance_output_loss: 0.4195 - val_valence_output_mae: 0.7961 - val_arousal_output_mae: 0.4102 - val_dominance_output_mae: 0.4978
# Epoch 4/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 13.1624 - valence_output_loss: 3.6988 - arousal_output_loss: 5.7363 - dominance_output_loss: 3.7272 - valence_output_mae: 0.7758 - arousal_output_mae: 0.4394 - dominance_output_mae: 0.4653
# Epoch 00004: val_loss improved from 1.77406 to 1.75515, saving model to ./trained_models/Resnet-04-dropout
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout/assets
# 1818/1817 [==============================] - 500s 275ms/step - loss: 13.1624 - valence_output_loss: 3.6988 - arousal_output_loss: 5.7363 - dominance_output_loss: 3.7272 - valence_output_mae: 0.7758 - arousal_output_mae: 0.4394 - dominance_output_mae: 0.4653 - val_loss: 1.7552 - val_valence_output_loss: 1.0402 - val_arousal_output_loss: 0.3103 - val_dominance_output_loss: 0.4047 - val_valence_output_mae: 0.8032 - val_arousal_output_mae: 0.4045 - val_dominance_output_mae: 0.4884
# Epoch 5/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.7295 - valence_output_loss: 0.9481 - arousal_output_loss: 0.3677 - dominance_output_loss: 0.4137 - valence_output_mae: 0.7592 - arousal_output_mae: 0.4283 - dominance_output_mae: 0.4580
# Epoch 00005: val_loss improved from 1.75515 to 1.74689, saving model to ./trained_models/Resnet-04-dropout
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout/assets
# 1818/1817 [==============================] - 493s 271ms/step - loss: 1.7295 - valence_output_loss: 0.9481 - arousal_output_loss: 0.3677 - dominance_output_loss: 0.4137 - valence_output_mae: 0.7592 - arousal_output_mae: 0.4283 - dominance_output_mae: 0.4580 - val_loss: 1.7469 - val_valence_output_loss: 1.0242 - val_arousal_output_loss: 0.3217 - val_dominance_output_loss: 0.4010 - val_valence_output_mae: 0.7938 - val_arousal_output_mae: 0.4223 - val_dominance_output_mae: 0.4828
# Epoch 6/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.6497 - valence_output_loss: 0.9343 - arousal_output_loss: 0.3551 - dominance_output_loss: 0.3603 - valence_output_mae: 0.7538 - arousal_output_mae: 0.4394 - dominance_output_mae: 0.4556
# Epoch 00006: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 474s 261ms/step - loss: 1.6497 - valence_output_loss: 0.9343 - arousal_output_loss: 0.3551 - dominance_output_loss: 0.3603 - valence_output_mae: 0.7538 - arousal_output_mae: 0.4394 - dominance_output_mae: 0.4556 - val_loss: 1.9551 - val_valence_output_loss: 1.0425 - val_arousal_output_loss: 0.3800 - val_dominance_output_loss: 0.5325 - val_valence_output_mae: 0.8046 - val_arousal_output_mae: 0.4568 - val_dominance_output_mae: 0.5935
# Epoch 7/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.6566 - valence_output_loss: 0.9150 - arousal_output_loss: 0.3548 - dominance_output_loss: 0.3868 - valence_output_mae: 0.7438 - arousal_output_mae: 0.4354 - dominance_output_mae: 0.4519
# Epoch 00007: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 474s 261ms/step - loss: 1.6566 - valence_output_loss: 0.9150 - arousal_output_loss: 0.3548 - dominance_output_loss: 0.3868 - valence_output_mae: 0.7438 - arousal_output_mae: 0.4354 - dominance_output_mae: 0.4519 - val_loss: 1.8394 - val_valence_output_loss: 1.0819 - val_arousal_output_loss: 0.3231 - val_dominance_output_loss: 0.4343 - val_valence_output_mae: 0.8116 - val_arousal_output_mae: 0.4133 - val_dominance_output_mae: 0.4954
# Epoch 8/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5635 - valence_output_loss: 0.8744 - arousal_output_loss: 0.3503 - dominance_output_loss: 0.3388 - valence_output_mae: 0.7345 - arousal_output_mae: 0.4357 - dominance_output_mae: 0.4448
# Epoch 00008: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 474s 261ms/step - loss: 1.5635 - valence_output_loss: 0.8744 - arousal_output_loss: 0.3503 - dominance_output_loss: 0.3388 - valence_output_mae: 0.7345 - arousal_output_mae: 0.4357 - dominance_output_mae: 0.4448 - val_loss: 1.7643 - val_valence_output_loss: 1.0382 - val_arousal_output_loss: 0.3186 - val_dominance_output_loss: 0.4076 - val_valence_output_mae: 0.7996 - val_arousal_output_mae: 0.4125 - val_dominance_output_mae: 0.4900
# Epoch 9/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5517 - valence_output_loss: 0.8687 - arousal_output_loss: 0.3514 - dominance_output_loss: 0.3316 - valence_output_mae: 0.7312 - arousal_output_mae: 0.4372 - dominance_output_mae: 0.4402
# Epoch 00009: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 481s 265ms/step - loss: 1.5517 - valence_output_loss: 0.8687 - arousal_output_loss: 0.3514 - dominance_output_loss: 0.3316 - valence_output_mae: 0.7312 - arousal_output_mae: 0.4372 - dominance_output_mae: 0.4402 - val_loss: 1.8116 - val_valence_output_loss: 1.0888 - val_arousal_output_loss: 0.3069 - val_dominance_output_loss: 0.4159 - val_valence_output_mae: 0.8127 - val_arousal_output_mae: 0.4032 - val_dominance_output_mae: 0.4831
# Epoch 10/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5256 - valence_output_loss: 0.8512 - arousal_output_loss: 0.3465 - dominance_output_loss: 0.3279 - valence_output_mae: 0.7230 - arousal_output_mae: 0.4327 - dominance_output_mae: 0.4389
# Epoch 00010: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 483s 266ms/step - loss: 1.5256 - valence_output_loss: 0.8512 - arousal_output_loss: 0.3465 - dominance_output_loss: 0.3279 - valence_output_mae: 0.7230 - arousal_output_mae: 0.4327 - dominance_output_mae: 0.4389 - val_loss: 1.7873 - val_valence_output_loss: 1.0402 - val_arousal_output_loss: 0.3511 - val_dominance_output_loss: 0.3960 - val_valence_output_mae: 0.8004 - val_arousal_output_mae: 0.4357 - val_dominance_output_mae: 0.4781
# Epoch 11/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5244 - valence_output_loss: 0.8470 - arousal_output_loss: 0.3468 - dominance_output_loss: 0.3306 - valence_output_mae: 0.7233 - arousal_output_mae: 0.4319 - dominance_output_mae: 0.4397
# Epoch 00011: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 484s 266ms/step - loss: 1.5244 - valence_output_loss: 0.8470 - arousal_output_loss: 0.3468 - dominance_output_loss: 0.3306 - valence_output_mae: 0.7233 - arousal_output_mae: 0.4319 - dominance_output_mae: 0.4397 - val_loss: 1.8109 - val_valence_output_loss: 1.0685 - val_arousal_output_loss: 0.2994 - val_dominance_output_loss: 0.4430 - val_valence_output_mae: 0.8084 - val_arousal_output_mae: 0.3996 - val_dominance_output_mae: 0.5011
# Epoch 12/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4872 - valence_output_loss: 0.8259 - arousal_output_loss: 0.3422 - dominance_output_loss: 0.3191 - valence_output_mae: 0.7136 - arousal_output_mae: 0.4295 - dominance_output_mae: 0.4330
# Epoch 00012: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 485s 267ms/step - loss: 1.4872 - valence_output_loss: 0.8259 - arousal_output_loss: 0.3422 - dominance_output_loss: 0.3191 - valence_output_mae: 0.7136 - arousal_output_mae: 0.4295 - dominance_output_mae: 0.4330 - val_loss: 1.9303 - val_valence_output_loss: 1.1685 - val_arousal_output_loss: 0.3406 - val_dominance_output_loss: 0.4212 - val_valence_output_mae: 0.8436 - val_arousal_output_mae: 0.4261 - val_dominance_output_mae: 0.4860
# Epoch 13/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.5460 - valence_output_loss: 0.8473 - arousal_output_loss: 0.3533 - dominance_output_loss: 0.3454 - valence_output_mae: 0.7127 - arousal_output_mae: 0.4267 - dominance_output_mae: 0.4298
# Epoch 00013: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 485s 267ms/step - loss: 1.5460 - valence_output_loss: 0.8473 - arousal_output_loss: 0.3533 - dominance_output_loss: 0.3454 - valence_output_mae: 0.7127 - arousal_output_mae: 0.4267 - dominance_output_mae: 0.4298 - val_loss: 1.8819 - val_valence_output_loss: 1.1308 - val_arousal_output_loss: 0.3085 - val_dominance_output_loss: 0.4426 - val_valence_output_mae: 0.8305 - val_arousal_output_mae: 0.4136 - val_dominance_output_mae: 0.5005
# Epoch 14/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4621 - valence_output_loss: 0.8135 - arousal_output_loss: 0.3342 - dominance_output_loss: 0.3145 - valence_output_mae: 0.7083 - arousal_output_mae: 0.4227 - dominance_output_mae: 0.4296
# Epoch 00014: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 485s 267ms/step - loss: 1.4621 - valence_output_loss: 0.8135 - arousal_output_loss: 0.3342 - dominance_output_loss: 0.3145 - valence_output_mae: 0.7083 - arousal_output_mae: 0.4227 - dominance_output_mae: 0.4296 - val_loss: 1.9162 - val_valence_output_loss: 1.1225 - val_arousal_output_loss: 0.2990 - val_dominance_output_loss: 0.4946 - val_valence_output_mae: 0.8297 - val_arousal_output_mae: 0.3919 - val_dominance_output_mae: 0.5325
# Epoch 15/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4491 - valence_output_loss: 0.8069 - arousal_output_loss: 0.3324 - dominance_output_loss: 0.3098 - valence_output_mae: 0.7065 - arousal_output_mae: 0.4210 - dominance_output_mae: 0.4254
# Epoch 00015: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 484s 266ms/step - loss: 1.4491 - valence_output_loss: 0.8069 - arousal_output_loss: 0.3324 - dominance_output_loss: 0.3098 - valence_output_mae: 0.7065 - arousal_output_mae: 0.4210 - dominance_output_mae: 0.4254 - val_loss: 1.7533 - val_valence_output_loss: 1.0627 - val_arousal_output_loss: 0.2916 - val_dominance_output_loss: 0.3989 - val_valence_output_mae: 0.8102 - val_arousal_output_mae: 0.3881 - val_dominance_output_mae: 0.4771
# Epoch 16/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.7839 - valence_output_loss: 0.9171 - arousal_output_loss: 0.3733 - dominance_output_loss: 0.4934 - valence_output_mae: 0.7027 - arousal_output_mae: 0.4197 - dominance_output_mae: 0.4296
# Epoch 00016: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 484s 266ms/step - loss: 1.7839 - valence_output_loss: 0.9171 - arousal_output_loss: 0.3733 - dominance_output_loss: 0.4934 - valence_output_mae: 0.7027 - arousal_output_mae: 0.4197 - dominance_output_mae: 0.4296 - val_loss: 1.7740 - val_valence_output_loss: 1.0700 - val_arousal_output_loss: 0.2981 - val_dominance_output_loss: 0.4059 - val_valence_output_mae: 0.8149 - val_arousal_output_mae: 0.3904 - val_dominance_output_mae: 0.4892
# Epoch 17/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4085 - valence_output_loss: 0.7854 - arousal_output_loss: 0.3200 - dominance_output_loss: 0.3031 - valence_output_mae: 0.6974 - arousal_output_mae: 0.4104 - dominance_output_mae: 0.4207
# Epoch 00017: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 483s 266ms/step - loss: 1.4085 - valence_output_loss: 0.7854 - arousal_output_loss: 0.3200 - dominance_output_loss: 0.3031 - valence_output_mae: 0.6974 - arousal_output_mae: 0.4104 - dominance_output_mae: 0.4207 - val_loss: 1.8383 - val_valence_output_loss: 1.1172 - val_arousal_output_loss: 0.2875 - val_dominance_output_loss: 0.4336 - val_valence_output_mae: 0.8239 - val_arousal_output_mae: 0.3861 - val_dominance_output_mae: 0.4927
# Epoch 18/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4057 - valence_output_loss: 0.7842 - arousal_output_loss: 0.3202 - dominance_output_loss: 0.3013 - valence_output_mae: 0.6970 - arousal_output_mae: 0.4098 - dominance_output_mae: 0.4206
# Epoch 00018: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 483s 266ms/step - loss: 1.4057 - valence_output_loss: 0.7842 - arousal_output_loss: 0.3202 - dominance_output_loss: 0.3013 - valence_output_mae: 0.6970 - arousal_output_mae: 0.4098 - dominance_output_mae: 0.4206 - val_loss: 1.7843 - val_valence_output_loss: 1.0777 - val_arousal_output_loss: 0.2874 - val_dominance_output_loss: 0.4191 - val_valence_output_mae: 0.8118 - val_arousal_output_mae: 0.3833 - val_dominance_output_mae: 0.4854
# Epoch 19/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.3875 - valence_output_loss: 0.7726 - arousal_output_loss: 0.3156 - dominance_output_loss: 0.2992 - valence_output_mae: 0.6917 - arousal_output_mae: 0.4074 - dominance_output_mae: 0.4187
# Epoch 00019: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 484s 266ms/step - loss: 1.3875 - valence_output_loss: 0.7726 - arousal_output_loss: 0.3156 - dominance_output_loss: 0.2992 - valence_output_mae: 0.6917 - arousal_output_mae: 0.4074 - dominance_output_mae: 0.4187 - val_loss: 1.7964 - val_valence_output_loss: 1.0900 - val_arousal_output_loss: 0.3063 - val_dominance_output_loss: 0.4001 - val_valence_output_mae: 0.8159 - val_arousal_output_mae: 0.3990 - val_dominance_output_mae: 0.4795
# Epoch 20/1000
# 1818/1817 [==============================] - ETA: 0s - loss: 1.4955 - valence_output_loss: 0.8708 - arousal_output_loss: 0.3181 - dominance_output_loss: 0.3066 - valence_output_mae: 0.6971 - arousal_output_mae: 0.4034 - dominance_output_mae: 0.4209
# Epoch 00020: val_loss did not improve from 1.74689
# 1818/1817 [==============================] - 484s 266ms/step - loss: 1.4955 - valence_output_loss: 0.8708 - arousal_output_loss: 0.3181 - dominance_output_loss: 0.3066 - valence_output_mae: 0.6971 - arousal_output_mae: 0.4034 - dominance_output_mae: 0.4209 - val_loss: 1.7732 - val_valence_output_loss: 1.0858 - val_arousal_output_loss: 0.2741 - val_dominance_output_loss: 0.4133 - val_valence_output_mae: 0.8170 - val_arousal_output_mae: 0.3774 - val_dominance_output_mae: 0.4834

# %% [markdown]
# ## Fine-tuning

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("./trained_models/Resnet-04-dropout")

# %%
len(model.layers)
# Out:
# 182

# %%
fine_tune_at = 150

# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[fine_tune_at:]:
  layer.trainable = True

for layer in model.layers[:fine_tune_at]:
    layer.trainable = False

# %%
model.summary()
# Out:
# [0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# top_dropout (Dropout)           (None, 7, 7, 2048)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100352)       0           top_dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          51380736    flatten_1[0][0]
# __________________________________________________________________________________________________
# valence_output (Dense)          (None, 1)            513         dense[0][0]
# __________________________________________________________________________________________________
# arousal_output (Dense)          (None, 1)            513         dense[0][0]
# __________________________________________________________________________________________________
# dominance_output (Dense)        (None, 1)            513         dense[0][0]
# ==================================================================================================
# Total params: 74,978,179
# Trainable params: 61,376,515
# Non-trainable params: 13,601,664
# __________________________________________________________________________________________________

# %%
import tensorflow

filename='./metric_logs/resnet-04-dropout-finetuned-log.csv'
history_logger = tensorflow.keras.callbacks.CSVLogger(filename, separator=",", append=True)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, mode='min', min_delta=0.0001),
    ModelCheckpoint('./trained_models/Resnet-04-dropout-finetuned', monitor='val_loss', verbose=1, save_best_only=True, mode='min'),
    history_logger
]

batch_size = 32
trainidx = len(train_file_list)
testidx = len(test_file_list)
valididx = len(valid_file_list)

# %%
opt = Adam(learning_rate=0.0001)

model.compile(optimizer=opt, run_eagerly=True,
              loss={'valence_output': 'mse', 'arousal_output': 'mse', 'dominance_output': 'mse'},
              metrics={'valence_output': 'mae', 'arousal_output': 'mae', 'dominance_output': 'mae'})

# %%
history = model.fit(gen_train, epochs=100, steps_per_epoch=trainidx/batch_size, validation_data=gen_valid, validation_steps=valididx/batch_size, callbacks=callbacks, batch_size=32)

def plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['dominance_output_mae'], label='Dominance Train MAE')
    axes[0].plot(history.history['val_dominance_output_mae'], label='Dominance Val MAE')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()

    axes[1].plot(history.history['arousal_output_mae'], label='Arousal Train MAE')
    axes[1].plot(history.history['val_arousal_output_mae'], label='Arousal Val MAE')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['valence_output_mae'], label='Valence Train MAE')
    axes[2].plot(history.history['val_valence_output_mae'], label='Valence Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

model.save('b4_mixedinput_fc_1024_512.h5')
# Out:
# utput_loss: 0.0959 - valence_output_mae: 0.3503 - arousal_output_mae: 0.4722 - dominance_output_mae: 0.2329 - val_loss: 1.6963 - val_valence_output_loss: 1.0289 - val_arousal_output_loss: 0.2884 - val_dominance_output_loss: 0.3790 - val_valence_output_mae: 0.7924 - val_arousal_output_mae: 0.3867 - val_dominance_output_mae: 0.4653
# Epoch 17/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7369 - valence_output_loss: 0.2060 - arousal_output_loss: 0.4341 - dominance_output_loss: 0.0968 - valence_output_mae: 0.3500 - arousal_output_mae: 0.4699 - dominance_output_mae: 0.2341
# Epoch 00017: val_loss did not improve from 1.69335
# 1818/1817 [==============================] - 478s 263ms/step - loss: 0.7369 - valence_output_loss: 0.2060 - arousal_output_loss: 0.4341 - dominance_output_loss: 0.0968 - valence_output_mae: 0.3500 - arousal_output_mae: 0.4699 - dominance_output_mae: 0.2341 - val_loss: 1.7046 - val_valence_output_loss: 1.0194 - val_arousal_output_loss: 0.3090 - val_dominance_output_loss: 0.3762 - val_valence_output_mae: 0.7889 - val_arousal_output_mae: 0.4007 - val_dominance_output_mae: 0.4611
# Epoch 18/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7191 - valence_output_loss: 0.1991 - arousal_output_loss: 0.4238 - dominance_output_loss: 0.0962 - valence_output_mae: 0.3435 - arousal_output_mae: 0.4650 - dominance_output_mae: 0.2333
# Epoch 00018: val_loss improved from 1.69335 to 1.69030, saving model to ./trained_models/Resnet-04-dropout-finetuned
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout-finetuned/assets
# 1818/1817 [==============================] - 498s 274ms/step - loss: 0.7191 - valence_output_loss: 0.1991 - arousal_output_loss: 0.4238 - dominance_output_loss: 0.0962 - valence_output_mae: 0.3435 - arousal_output_mae: 0.4650 - dominance_output_mae: 0.2333 - val_loss: 1.6903 - val_valence_output_loss: 1.0256 - val_arousal_output_loss: 0.2865 - val_dominance_output_loss: 0.3782 - val_valence_output_mae: 0.7927 - val_arousal_output_mae: 0.3865 - val_dominance_output_mae: 0.4609
# Epoch 19/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.7152 - valence_output_loss: 0.1915 - arousal_output_loss: 0.4296 - dominance_output_loss: 0.0940 - valence_output_mae: 0.3370 - arousal_output_mae: 0.4661 - dominance_output_mae: 0.2302
# Epoch 00019: val_loss did not improve from 1.69030
# 1818/1817 [==============================] - 478s 263ms/step - loss: 0.7152 - valence_output_loss: 0.1915 - arousal_output_loss: 0.4296 - dominance_output_loss: 0.0940 - valence_output_mae: 0.3370 - arousal_output_mae: 0.4661 - dominance_output_mae: 0.2302 - val_loss: 1.6921 - val_valence_output_loss: 1.0311 - val_arousal_output_loss: 0.2839 - val_dominance_output_loss: 0.3772 - val_valence_output_mae: 0.7952 - val_arousal_output_mae: 0.3812 - val_dominance_output_mae: 0.4629
# Epoch 20/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6952 - valence_output_loss: 0.1798 - arousal_output_loss: 0.4231 - dominance_output_loss: 0.0922 - valence_output_mae: 0.3261 - arousal_output_mae: 0.4637 - dominance_output_mae: 0.2274
# Epoch 00020: val_loss did not improve from 1.69030
# 1818/1817 [==============================] - 489s 269ms/step - loss: 0.6952 - valence_output_loss: 0.1798 - arousal_output_loss: 0.4231 - dominance_output_loss: 0.0922 - valence_output_mae: 0.3261 - arousal_output_mae: 0.4637 - dominance_output_mae: 0.2274 - val_loss: 1.7170 - val_valence_output_loss: 1.0385 - val_arousal_output_loss: 0.2953 - val_dominance_output_loss: 0.3832 - val_valence_output_mae: 0.7996 - val_arousal_output_mae: 0.3909 - val_dominance_output_mae: 0.4661
# Epoch 21/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6890 - valence_output_loss: 0.1736 - arousal_output_loss: 0.4253 - dominance_output_loss: 0.0901 - valence_output_mae: 0.3203 - arousal_output_mae: 0.4654 - dominance_output_mae: 0.2248
# Epoch 00021: val_loss improved from 1.69030 to 1.67526, saving model to ./trained_models/Resnet-04-dropout-finetuned
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout-finetuned/assets
# 1818/1817 [==============================] - 510s 281ms/step - loss: 0.6890 - valence_output_loss: 0.1736 - arousal_output_loss: 0.4253 - dominance_output_loss: 0.0901 - valence_output_mae: 0.3203 - arousal_output_mae: 0.4654 - dominance_output_mae: 0.2248 - val_loss: 1.6753 - val_valence_output_loss: 1.0097 - val_arousal_output_loss: 0.2780 - val_dominance_output_loss: 0.3875 - val_valence_output_mae: 0.7877 - val_arousal_output_mae: 0.3796 - val_dominance_output_mae: 0.4806
# Epoch 22/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6751 - valence_output_loss: 0.1639 - arousal_output_loss: 0.4212 - dominance_output_loss: 0.0899 - valence_output_mae: 0.3116 - arousal_output_mae: 0.4608 - dominance_output_mae: 0.2238
# Epoch 00022: val_loss did not improve from 1.67526
# 1818/1817 [==============================] - 492s 270ms/step - loss: 0.6751 - valence_output_loss: 0.1639 - arousal_output_loss: 0.4212 - dominance_output_loss: 0.0899 - valence_output_mae: 0.3116 - arousal_output_mae: 0.4608 - dominance_output_mae: 0.2238 - val_loss: 1.6912 - val_valence_output_loss: 1.0306 - val_arousal_output_loss: 0.2831 - val_dominance_output_loss: 0.3775 - val_valence_output_mae: 0.7923 - val_arousal_output_mae: 0.3823 - val_dominance_output_mae: 0.4601
# Epoch 23/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6646 - valence_output_loss: 0.1572 - arousal_output_loss: 0.4197 - dominance_output_loss: 0.0877 - valence_output_mae: 0.3042 - arousal_output_mae: 0.4604 - dominance_output_mae: 0.2208
# Epoch 00023: val_loss improved from 1.67526 to 1.67403, saving model to ./trained_models/Resnet-04-dropout-finetuned
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout-finetuned/assets
# 1818/1817 [==============================] - 512s 281ms/step - loss: 0.6646 - valence_output_loss: 0.1572 - arousal_output_loss: 0.4197 - dominance_output_loss: 0.0877 - valence_output_mae: 0.3042 - arousal_output_mae: 0.4604 - dominance_output_mae: 0.2208 - val_loss: 1.6740 - val_valence_output_loss: 1.0171 - val_arousal_output_loss: 0.2849 - val_dominance_output_loss: 0.3720 - val_valence_output_mae: 0.7899 - val_arousal_output_mae: 0.3823 - val_dominance_output_mae: 0.4574
# Epoch 24/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6475 - valence_output_loss: 0.1499 - arousal_output_loss: 0.4122 - dominance_output_loss: 0.0854 - valence_output_mae: 0.2971 - arousal_output_mae: 0.4559 - dominance_output_mae: 0.2183
# Epoch 00024: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 493s 271ms/step - loss: 0.6475 - valence_output_loss: 0.1499 - arousal_output_loss: 0.4122 - dominance_output_loss: 0.0854 - valence_output_mae: 0.2971 - arousal_output_mae: 0.4559 - dominance_output_mae: 0.2183 - val_loss: 1.6990 - val_valence_output_loss: 1.0318 - val_arousal_output_loss: 0.2881 - val_dominance_output_loss: 0.3791 - val_valence_output_mae: 0.7963 - val_arousal_output_mae: 0.3855 - val_dominance_output_mae: 0.4684
# Epoch 25/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6449 - valence_output_loss: 0.1435 - arousal_output_loss: 0.4168 - dominance_output_loss: 0.0845 - valence_output_mae: 0.2905 - arousal_output_mae: 0.4587 - dominance_output_mae: 0.2170
# Epoch 00025: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 492s 271ms/step - loss: 0.6449 - valence_output_loss: 0.1435 - arousal_output_loss: 0.4168 - dominance_output_loss: 0.0845 - valence_output_mae: 0.2905 - arousal_output_mae: 0.4587 - dominance_output_mae: 0.2170 - val_loss: 1.6908 - val_valence_output_loss: 1.0331 - val_arousal_output_loss: 0.2833 - val_dominance_output_loss: 0.3744 - val_valence_output_mae: 0.7958 - val_arousal_output_mae: 0.3812 - val_dominance_output_mae: 0.4588
# Epoch 26/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6287 - valence_output_loss: 0.1374 - arousal_output_loss: 0.4074 - dominance_output_loss: 0.0840 - valence_output_mae: 0.2848 - arousal_output_mae: 0.4519 - dominance_output_mae: 0.2157
# Epoch 00026: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 491s 270ms/step - loss: 0.6287 - valence_output_loss: 0.1374 - arousal_output_loss: 0.4074 - dominance_output_loss: 0.0840 - valence_output_mae: 0.2848 - arousal_output_mae: 0.4519 - dominance_output_mae: 0.2157 - val_loss: 1.6761 - val_valence_output_loss: 1.0235 - val_arousal_output_loss: 0.2834 - val_dominance_output_loss: 0.3692 - val_valence_output_mae: 0.7919 - val_arousal_output_mae: 0.3831 - val_dominance_output_mae: 0.4604
# Epoch 27/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6167 - valence_output_loss: 0.1297 - arousal_output_loss: 0.4053 - dominance_output_loss: 0.0817 - valence_output_mae: 0.2766 - arousal_output_mae: 0.4520 - dominance_output_mae: 0.2129
# Epoch 00027: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 494s 271ms/step - loss: 0.6167 - valence_output_loss: 0.1297 - arousal_output_loss: 0.4053 - dominance_output_loss: 0.0817 - valence_output_mae: 0.2766 - arousal_output_mae: 0.4520 - dominance_output_mae: 0.2129 - val_loss: 1.7059 - val_valence_output_loss: 1.0328 - val_arousal_output_loss: 0.2965 - val_dominance_output_loss: 0.3766 - val_valence_output_mae: 0.7948 - val_arousal_output_mae: 0.3906 - val_dominance_output_mae: 0.4647
# Epoch 28/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6107 - valence_output_loss: 0.1262 - arousal_output_loss: 0.4017 - dominance_output_loss: 0.0828 - valence_output_mae: 0.2729 - arousal_output_mae: 0.4497 - dominance_output_mae: 0.2139
# Epoch 00028: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 493s 271ms/step - loss: 0.6107 - valence_output_loss: 0.1262 - arousal_output_loss: 0.4017 - dominance_output_loss: 0.0828 - valence_output_mae: 0.2729 - arousal_output_mae: 0.4497 - dominance_output_mae: 0.2139 - val_loss: 1.6797 - val_valence_output_loss: 1.0211 - val_arousal_output_loss: 0.2884 - val_dominance_output_loss: 0.3702 - val_valence_output_mae: 0.7896 - val_arousal_output_mae: 0.3836 - val_dominance_output_mae: 0.4591
# Epoch 29/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.6025 - valence_output_loss: 0.1206 - arousal_output_loss: 0.4012 - dominance_output_loss: 0.0807 - valence_output_mae: 0.2661 - arousal_output_mae: 0.4489 - dominance_output_mae: 0.2111
# Epoch 00029: val_loss did not improve from 1.67403
# 1818/1817 [==============================] - 493s 271ms/step - loss: 0.6025 - valence_output_loss: 0.1206 - arousal_output_loss: 0.4012 - dominance_output_loss: 0.0807 - valence_output_mae: 0.2661 - arousal_output_mae: 0.4489 - dominance_output_mae: 0.2111 - val_loss: 1.7071 - val_valence_output_loss: 1.0435 - val_arousal_output_loss: 0.2886 - val_dominance_output_loss: 0.3750 - val_valence_output_mae: 0.7991 - val_arousal_output_mae: 0.3834 - val_dominance_output_mae: 0.4591
# Epoch 30/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5885 - valence_output_loss: 0.1145 - arousal_output_loss: 0.3949 - dominance_output_loss: 0.0791 - valence_output_mae: 0.2603 - arousal_output_mae: 0.4461 - dominance_output_mae: 0.2088
# Epoch 00030: val_loss improved from 1.67403 to 1.65136, saving model to ./trained_models/Resnet-04-dropout-finetuned
# INFO:tensorflow:Assets written to: ./trained_models/Resnet-04-dropout-finetuned/assets
# 1818/1817 [==============================] - 512s 282ms/step - loss: 0.5885 - valence_output_loss: 0.1145 - arousal_output_loss: 0.3949 - dominance_output_loss: 0.0791 - valence_output_mae: 0.2603 - arousal_output_mae: 0.4461 - dominance_output_mae: 0.2088 - val_loss: 1.6514 - val_valence_output_loss: 1.0130 - val_arousal_output_loss: 0.2729 - val_dominance_output_loss: 0.3654 - val_valence_output_mae: 0.7889 - val_arousal_output_mae: 0.3765 - val_dominance_output_mae: 0.4546
# Epoch 31/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5869 - valence_output_loss: 0.1110 - arousal_output_loss: 0.3965 - dominance_output_loss: 0.0795 - valence_output_mae: 0.2555 - arousal_output_mae: 0.4459 - dominance_output_mae: 0.2086
# Epoch 00031: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 494s 272ms/step - loss: 0.5869 - valence_output_loss: 0.1110 - arousal_output_loss: 0.3965 - dominance_output_loss: 0.0795 - valence_output_mae: 0.2555 - arousal_output_mae: 0.4459 - dominance_output_mae: 0.2086 - val_loss: 1.6853 - val_valence_output_loss: 1.0302 - val_arousal_output_loss: 0.2826 - val_dominance_output_loss: 0.3725 - val_valence_output_mae: 0.7937 - val_arousal_output_mae: 0.3792 - val_dominance_output_mae: 0.4568
# Epoch 32/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5689 - valence_output_loss: 0.1060 - arousal_output_loss: 0.3854 - dominance_output_loss: 0.0775 - valence_output_mae: 0.2497 - arousal_output_mae: 0.4395 - dominance_output_mae: 0.2059
# Epoch 00032: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 492s 271ms/step - loss: 0.5689 - valence_output_loss: 0.1060 - arousal_output_loss: 0.3854 - dominance_output_loss: 0.0775 - valence_output_mae: 0.2497 - arousal_output_mae: 0.4395 - dominance_output_mae: 0.2059 - val_loss: 1.6575 - val_valence_output_loss: 1.0144 - val_arousal_output_loss: 0.2794 - val_dominance_output_loss: 0.3638 - val_valence_output_mae: 0.7895 - val_arousal_output_mae: 0.3802 - val_dominance_output_mae: 0.4556
# Epoch 33/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5656 - valence_output_loss: 0.1017 - arousal_output_loss: 0.3868 - dominance_output_loss: 0.0771 - valence_output_mae: 0.2448 - arousal_output_mae: 0.4401 - dominance_output_mae: 0.2056
# Epoch 00033: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 494s 272ms/step - loss: 0.5656 - valence_output_loss: 0.1017 - arousal_output_loss: 0.3868 - dominance_output_loss: 0.0771 - valence_output_mae: 0.2448 - arousal_output_mae: 0.4401 - dominance_output_mae: 0.2056 - val_loss: 1.6834 - val_valence_output_loss: 1.0320 - val_arousal_output_loss: 0.2780 - val_dominance_output_loss: 0.3734 - val_valence_output_mae: 0.7934 - val_arousal_output_mae: 0.3765 - val_dominance_output_mae: 0.4543
# Epoch 34/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5570 - valence_output_loss: 0.0981 - arousal_output_loss: 0.3828 - dominance_output_loss: 0.0761 - valence_output_mae: 0.2405 - arousal_output_mae: 0.4392 - dominance_output_mae: 0.2037
# Epoch 00034: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 493s 271ms/step - loss: 0.5570 - valence_output_loss: 0.0981 - arousal_output_loss: 0.3828 - dominance_output_loss: 0.0761 - valence_output_mae: 0.2405 - arousal_output_mae: 0.4392 - dominance_output_mae: 0.2037 - val_loss: 1.6838 - val_valence_output_loss: 1.0334 - val_arousal_output_loss: 0.2758 - val_dominance_output_loss: 0.3747 - val_valence_output_mae: 0.7969 - val_arousal_output_mae: 0.3744 - val_dominance_output_mae: 0.4631
# Epoch 35/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5508 - valence_output_loss: 0.0935 - arousal_output_loss: 0.3821 - dominance_output_loss: 0.0752 - valence_output_mae: 0.2343 - arousal_output_mae: 0.4364 - dominance_output_mae: 0.2024
# Epoch 00035: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5508 - valence_output_loss: 0.0935 - arousal_output_loss: 0.3821 - dominance_output_loss: 0.0752 - valence_output_mae: 0.2343 - arousal_output_mae: 0.4364 - dominance_output_mae: 0.2024 - val_loss: 1.6757 - val_valence_output_loss: 1.0339 - val_arousal_output_loss: 0.2778 - val_dominance_output_loss: 0.3641 - val_valence_output_mae: 0.7969 - val_arousal_output_mae: 0.3773 - val_dominance_output_mae: 0.4527
# Epoch 36/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5433 - valence_output_loss: 0.0915 - arousal_output_loss: 0.3765 - dominance_output_loss: 0.0753 - valence_output_mae: 0.2321 - arousal_output_mae: 0.4346 - dominance_output_mae: 0.2022
# Epoch 00036: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5433 - valence_output_loss: 0.0915 - arousal_output_loss: 0.3765 - dominance_output_loss: 0.0753 - valence_output_mae: 0.2321 - arousal_output_mae: 0.4346 - dominance_output_mae: 0.2022 - val_loss: 1.6988 - val_valence_output_loss: 1.0361 - val_arousal_output_loss: 0.2902 - val_dominance_output_loss: 0.3726 - val_valence_output_mae: 0.7965 - val_arousal_output_mae: 0.3861 - val_dominance_output_mae: 0.4569
# Epoch 37/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5364 - valence_output_loss: 0.0881 - arousal_output_loss: 0.3737 - dominance_output_loss: 0.0745 - valence_output_mae: 0.2281 - arousal_output_mae: 0.4323 - dominance_output_mae: 0.2013
# Epoch 00037: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5364 - valence_output_loss: 0.0881 - arousal_output_loss: 0.3737 - dominance_output_loss: 0.0745 - valence_output_mae: 0.2281 - arousal_output_mae: 0.4323 - dominance_output_mae: 0.2013 - val_loss: 1.6822 - val_valence_output_loss: 1.0403 - val_arousal_output_loss: 0.2765 - val_dominance_output_loss: 0.3653 - val_valence_output_mae: 0.7970 - val_arousal_output_mae: 0.3749 - val_dominance_output_mae: 0.4528
# Epoch 38/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5251 - valence_output_loss: 0.0832 - arousal_output_loss: 0.3689 - dominance_output_loss: 0.0729 - valence_output_mae: 0.2225 - arousal_output_mae: 0.4289 - dominance_output_mae: 0.1992
# Epoch 00038: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5251 - valence_output_loss: 0.0832 - arousal_output_loss: 0.3689 - dominance_output_loss: 0.0729 - valence_output_mae: 0.2225 - arousal_output_mae: 0.4289 - dominance_output_mae: 0.1992 - val_loss: 1.6738 - val_valence_output_loss: 1.0319 - val_arousal_output_loss: 0.2733 - val_dominance_output_loss: 0.3686 - val_valence_output_mae: 0.7969 - val_arousal_output_mae: 0.3729 - val_dominance_output_mae: 0.4570
# Epoch 39/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5245 - valence_output_loss: 0.0820 - arousal_output_loss: 0.3691 - dominance_output_loss: 0.0735 - valence_output_mae: 0.2198 - arousal_output_mae: 0.4293 - dominance_output_mae: 0.1991
# Epoch 00039: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5245 - valence_output_loss: 0.0820 - arousal_output_loss: 0.3691 - dominance_output_loss: 0.0735 - valence_output_mae: 0.2198 - arousal_output_mae: 0.4293 - dominance_output_mae: 0.1991 - val_loss: 1.6972 - val_valence_output_loss: 1.0265 - val_arousal_output_loss: 0.3021 - val_dominance_output_loss: 0.3686 - val_valence_output_mae: 0.7898 - val_arousal_output_mae: 0.3943 - val_dominance_output_mae: 0.4503
# Epoch 40/100
# 1818/1817 [==============================] - ETA: 0s - loss: 0.5089 - valence_output_loss: 0.0785 - arousal_output_loss: 0.3581 - dominance_output_loss: 0.0723 - valence_output_mae: 0.2150 - arousal_output_mae: 0.4242 - dominance_output_mae: 0.1976
# Epoch 00040: val_loss did not improve from 1.65136
# 1818/1817 [==============================] - 495s 272ms/step - loss: 0.5089 - valence_output_loss: 0.0785 - arousal_output_loss: 0.3581 - dominance_output_loss: 0.0723 - valence_output_mae: 0.2150 - arousal_output_mae: 0.4242 - dominance_output_mae: 0.1976 - val_loss: 1.6673 - val_valence_output_loss: 1.0322 - val_arousal_output_loss: 0.2666 - val_dominance_output_loss: 0.3684 - val_valence_output_mae: 0.7949 - val_arousal_output_mae: 0.3701 - val_dominance_output_mae: 0.4533

# %% [markdown]
# Best validation loss:  1.65136
